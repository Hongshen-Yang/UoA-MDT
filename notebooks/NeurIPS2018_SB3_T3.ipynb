# %% [markdown]
# # NeurIPS2018_SB3
#
# This is a modification version based on the first notebook from [FinRL-tutorial](https://github.com/AI4Finance-Foundation/FinRL-Tutorials)
#
# https://github.com/AI4Finance-Foundation/FinRL-Tutorials/blob/master/1-Introduction/Stock_NeurIPS2018_SB3.ipynb
#
# ## Part 1. Task Discription
# DRL agent training for cryptocurrency trading.
#
# This task is modeled as a Markov Decision Process (MDP), and the objective function is maximizing (expected) cumulative return.
#
# We specify the state-action-reward as follows:
#
# * **State s**: The state space represents an agent's perception of the market environment. Just like a human trader analyzing various information, here our agent passively observes many features and learns by interacting with the market environment (usually by replaying historical data).
#
# * **Action a**: The action space includes allowed actions that an agent can take at each state. For example, a ∈ {−1, 0, 1}, where −1, 0, 1 represent selling, holding, and buying. When an action operates single crypto a ∈{−k, ..., −1, 0, 1, ..., k}, e.g.. "Buy 10 units of BTC" or "Sell 10 units of BTC" are 10 or −10, respectively
#
# * **Reward function r(s, a, s′)**: Reward is an incentive for an agent to learn a better policy. For example, it can be the change of the portfolio value when taking a at state s and arriving at new state s', i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio values at state s′ and s, respectively
#
# **Market environment**: Cryptocurrencies from Binance

# %% [markdown]
# ##  Part 2. Import Packages

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime, sqlite3, zipfile, os

# %matplotlib inline
# from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from T3.env_stocktrading import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from stable_baselines3.common.logger import configure
from finrl.meta.data_processor import DataProcessor

from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline
from pprint import pprint

import sys
sys.path.append("../FinRL")

import itertools
# Out:
# /Users/HSY/miniconda3/envs/uoa-mdt/lib/python3.10/site-packages/pyfolio/pos.py:26: UserWarning: Module "zipline.assets" not found; mutltipliers will not be applied to position notionals.
#   warnings.warn(

# %% [markdown]
# ### Create Folders

# %%
from finrl import config
from finrl import config_tickers
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)
check_and_make_directories([TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %% [markdown]
# ### Read Data
#
# Read data from `binance-public-data`

# %%
TRAIN_START_DATE = '2017-08-17'
TRAIN_END_DATE = '2022-12-31'
TRADE_START_DATE = '2023-01-01'
TRADE_END_DATE = '2023-07-31'

# %% [raw]
# # This is read from SQLite database
#
# # Connect to the SQLite database
# conn = sqlite3.connect('../sqlite.db')
#
# table_name = 'kline_copy'
#
# # Read data from the table into a DataFrame
# query = f'SELECT * FROM {table_name};'
# sql_df = pd.read_sql_query(query, conn)
#
# # Close the database connection
# conn.close()
#
# # Create a new DataFrame with renamed columns
# df = sql_df[['start_time', 'open', 'high', 'low', 'close', 'base_vol', 'symbol', 'id']].rename(
#     columns={
#     'start_time': 'start_time',
#     'open': 'open',
#     'high': 'high',
#     'low': 'low',
#     'close': 'close',
#     'base_vol': 'volume',
#     'symbol': 'tic',
#     'id': 'id'
#     })
#
# print(df)

# %%
# List of symbols to merge
symbols = ['BTCUSDT', 'ETHUSDT']

# List to store individual DataFrames
rawdfs = []

# Loop through each symbol
for symbol in symbols:
    directory = f'../mdt_utils/binance-public-data/python/data/spot/monthly/klines/{symbol}/1d/'
    
    # Loop through each zip file in the directory
    for file_name in os.listdir(directory):
        if file_name.endswith('.zip'):
            with zipfile.ZipFile(os.path.join(directory, file_name), 'r') as zip_ref:
                # only one CSV file in each zip archive
                csv_file = zip_ref.namelist()[0]
                with zip_ref.open(csv_file) as csv_fp:
                    # Read the CSV data into a DataFrame
                    temp_df = pd.read_csv(csv_fp, header=None)
                    temp_df.columns = ['open_time', 'open', 'high', 'low', 'close', 'volume', 'close_time', 'quote_asset_volume', 'number_of_trades', 'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume', 'ignore']
                    temp_df['date'] = pd.to_datetime(temp_df['close_time'], unit='ms').dt.strftime('%Y-%m-%d')
                    temp_df['day'] = (pd.to_datetime(temp_df['date']) - pd.to_datetime(temp_df['date'].iloc[0])).dt.days
                    temp_df['tic'] = symbol
                    rawdfs.append(temp_df[['date', 'open', 'high', 'low', 'close', 'volume', 'tic', 'day']])

# Concatenate all DataFrames into a single DataFrame
rawdf = pd.concat(rawdfs, ignore_index=True)

# Count the number of unique 'tic' values per date
tic_counts = rawdf.groupby('date')['tic'].nunique()

# Filter the DataFrame to keep only rows where all 'tic' values participate
df = rawdf[rawdf['date'].isin(tic_counts[tic_counts == len(rawdf['tic'].unique())].index)]
# Only wanted columns
df = df[['date', 'close', 'volume', 'tic', 'day']]

df.sort_values(['date','tic'],ignore_index=True).head()
# Out:
#          date    close       volume      tic  day
# 0  2017-08-17  4285.08   795.150377  BTCUSDT    0
# 1  2017-08-17   302.00  7030.710340  ETHUSDT    0
# 2  2017-08-18  4108.37  1199.888264  BTCUSDT    1
# 3  2017-08-18   293.96  9537.846460  ETHUSDT    1
# 4  2017-08-19  4139.98   381.309763  BTCUSDT    2

# %%
# Calculate the spread and total volume for each day
spread_df = df.groupby(['date']).agg({
    'close': lambda x: x.iloc[0] - x.iloc[1],  # BTCEUR - BTCGBP
    'volume': 'sum'  # Sum of volumes for both BTCEUR and BTCGBP
}).reset_index()
spread_df['tic']="Spread"

pivot_df = df.pivot(index='date', columns='tic', values='close').reset_index()
spread_df = pd.merge(spread_df, pivot_df, on='date')

# Calculate the 'day' column
spread_df['date'] = pd.to_datetime(spread_df['date'])
spread_df['day'] = (spread_df['date'] - spread_df['date'].iloc[0]).dt.days

spread_df['date'] = spread_df['date'].dt.strftime('%Y-%m-%d')

spread_df.tail(5)
# Out:
#             date     close        volume     tic   BTCUSDT  ETHUSDT   day
# 2170  2023-07-27  27361.50  186242.90216  Spread  29222.78  1861.28  2170
# 2171  2023-07-28  27439.95  162689.33097  Spread  29314.14  1874.19  2171
# 2172  2023-07-29  27472.44   83718.39534  Spread  29352.90  1880.46  2172
# 2173  2023-07-30  27419.30  174364.56461  Spread  29281.09  1861.79  2173
# 2174  2023-07-31  27376.11  190809.94304  Spread  29232.25  1856.14  2174

# %% [markdown]
# ## Part 4. Preprocess Data
#
# TODO: The default feature engineering is based on date. I need to rewrite into timestamp based method
#
# The dafult [data split](https://github.com/AI4Finance-Foundation/FinRL/blob/master/finrl/meta/preprocessor/preprocessors.py) is not applicable here. Need to manually redo it.

# %%
INDICATORS = ['macd', 'boll_ub', 'boll_lb', 'rsi_30', 'close_30_sma', 'close_60_sma']

fe = FeatureEngineer(
                    use_technical_indicator=True,
                    tech_indicator_list = INDICATORS,
                    use_vix=True,
                    use_turbulence=False,
                    user_defined_feature = False)

processed = fe.preprocess_data(spread_df)
# Out:
# Successfully added technical indicators
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (1496, 8)
# Successfully added vix

# %%
list_ticker = processed["tic"].unique().tolist()
list_date = list(pd.date_range(processed['date'].min(),processed['date'].max()).astype(str))
combination = list(itertools.product(list_date,list_ticker))

processed_full = pd.DataFrame(combination,columns=["date","tic"]).merge(processed,on=["date","tic"],how="left")
processed_full = processed_full[processed_full['date'].isin(processed['date'])]
processed_full = processed_full.sort_values(['date','tic'])

processed_full = processed_full.fillna(0)

# %%
processed_full.sort_values(['date'],ignore_index=True).tail(5)
# Out:
#             date     tic     close        volume   BTCUSDT  ETHUSDT     day  \
# 1491  2023-07-24  Spread  27326.50  316133.55161  29176.50  1850.00  2167.0
# 1492  2023-07-25  Spread  27371.25  173816.95780  29228.91  1857.66  2168.0
# 1493  2023-07-26  Spread  27479.96  306022.16696  29351.96  1872.00  2169.0
# 1494  2023-07-27  Spread  27361.50  186242.90216  29222.78  1861.28  2170.0
# 1495  2023-07-28  Spread  27439.95  162689.33097  29314.14  1874.19  2171.0
#
#             macd       boll_ub       boll_lb     rsi_30  close_30_sma  \
# 1491   52.653296  29123.677505  27444.978495  50.069584  28407.238000
# 1492   -5.265230  29141.878301  27304.457699  50.288501  28367.484333
# 1493  -41.910967  29169.657244  27219.748756  50.830267  28336.515667
# 1494  -79.594198  29172.175155  27106.001845  50.213388  28288.470333
# 1495 -101.952920  29159.477721  27020.755279  50.623912  28261.489000
#
#       close_60_sma    vix
# 1491  26870.975333  13.91
# 1492  26912.527333  13.86
# 1493  26953.453667  13.19
# 1494  26973.539333  14.41
# 1495  27000.141833  13.33

# %%
plt.plot(processed_full['date'], processed_full['close'])
plt.ylabel('Spread')
plt.title('Spread Movement')
plt.xticks(rotation=45)
plt.tight_layout()

max_ticks = 7  # Change this value as needed
plt.gca().xaxis.set_major_locator(matplotlib.ticker.MaxNLocator(integer=True, nbins=max_ticks))
# plt.gca().xaxis.set_major_formatter(DateFormatter('%Y-%m'))

plt.show()

# %% [markdown]
# ## Part 5. Build A Market Environment in OpenAI Gym-style
# The training process involves observing cryptocurrency price change, taking an action and reward's calculation. By interacting with the market environment, the agent will eventually derive a trading strategy that may maximize (expected) rewards.
#
# Our market environment, based on OpenAI Gym, simulates stock markets with historical market data.
#
# ### Data Split
# We split the data into training set and testing set as follows:

# %%
train = data_split(processed_full, TRAIN_START_DATE, TRAIN_END_DATE)
trade = data_split(processed_full, TRADE_START_DATE, TRADE_END_DATE)
train_length = len(train)
trade_length = len(trade)
print(f"Training Data length: {train_length}")
print(f"Trade Data Length: {trade_length}")
print(f"Indicators: {INDICATORS}")
# Out:
# Training Data length: 1353
# Trade Data Length: 143
# Indicators: ['macd', 'boll_ub', 'boll_lb', 'rsi_30', 'close_30_sma', 'close_60_sma']

# %% [markdown]
# Because we are trading with 2 assets as a pair, therefore we have only 1 pair_dimension
#
# `1`: Represents the cash balance. There's one element in the state for the agent's cash.
#
# `2 * stock_dimension`: Represents the stock prices and stock ownership. There are two elements for each stock: one for the stock price and one for the number of shares owned.
#
# `len(INDICATORS) * stock_dimension`: Represents the technical indicators for each stock. Each indicator contributes one element per stock.

# %%
stock_dimension = len(train.tic.unique())
state_space = 1 + 2*stock_dimension + len(symbols + INDICATORS)*stock_dimension
print(f"Spread Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Spread Dimension: 1, State Space: 11

# %%
# 0.1% was the default trading. However for pair trading, it should be doubled. 
buy_cost_list = sell_cost_list = [0.002] * stock_dimension
num_stock_shares = [0] * stock_dimension

env_kwargs = {
    "hmax": 10,
    "initial_amount": 100000,
    "num_stock_shares": num_stock_shares,
    "buy_cost_pct": buy_cost_list,
    "sell_cost_pct": sell_cost_list,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": symbols + INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4
}

e_train_gym = StockTradingEnv(df = train, **env_kwargs)

# %%
# 100000, cash balance
# 3983.08, spread distance
# 0, number of "spread" holding
# 4285.08, the price of first symbol
# 302.0, the price of second symbol
# 0.0, technical indicator value
# 4137.28040156547, technical indicator value
# 3660.2095984345297, technical indicator value
# 0.0, technical indicator value
# 3983.08, technical indicator value
# 3983.08 technical indicator value

e_train_gym.state
# Out:
# [100000,
#  3983.08,
#  0,
#  4285.08,
#  302.0,
#  0.0,
#  4137.28040156547,
#  3660.2095984345297,
#  0.0,
#  3983.08,
#  3983.08]

# %% [markdown]
# ### Environment for Training

# %%
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>

# %% [markdown]
# ## Part 6. Train DRL Agents
# * The DRL algorithms are from Stable Baselines 3. Users are also encouraged to try ElegantRL and Ray RLlib.
# * FinRL includes fine-tuned standard DRL algorithms, such as DQN, DDPG, Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.
#
# design their own DRL algorithms by adapting these DRL algorithms.

# %%
agent = DRLAgent(env = env_train)

if_using_a2c = True
if_using_ddpg = True
if_using_ppo = True
if_using_td3 = True
if_using_sac = True

# %% [markdown]
# ### Agent 1: A2C

# %%
agent = DRLAgent(env = env_train)
model_a2c = agent.get_model("a2c")

if if_using_a2c:
  # set up logger
  tmp_path = RESULTS_DIR + '/a2c'
  new_logger_a2c = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_a2c.set_logger(new_logger_a2c)
# Out:
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0007}
# Using cpu device
# Logging to results/a2c

# %%
trained_a2c = agent.train_model(model=model_a2c, 
                             tb_log_name='a2c',
                             total_timesteps=50000) if if_using_a2c else None
# Out:
# ------------------------------------
# | time/                 |          |
# |    fps                | 1481     |
# |    iterations         | 100      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -1.42    |
# |    explained_variance | -0.00459 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 8.11     |
# |    reward             | -5.2094  |
# |    std                | 0.998    |
# |    value_loss         | 60.1     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1724     |
# |    iterations         | 200      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -1.42    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | -3.7     |
# |    reward             | 31.21628 |
# |    std                | 0.996    |
# |    value_loss         | 398      |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1834      |
# |    iterations         | 300       |
# |    time_elapsed       | 0         |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -1.42     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | -65.1     |
# |    reward             | 37.948906 |
# |    std                | 1         |
# |    value_loss         | 6.8e+03   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1897      |
# |    iterations         | 400       |
# |    time_elapsed       | 1         |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -1.43     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | 45.9      |
# |    reward             | 20.918541 |
# |    std                | 1.01      |
# |    value_loss         | 1.44e+03  |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 1936        |
# |    iterations         | 500         |
# |    time_elapsed       | 1           |
# |    total_timesteps    | 2500        |
# | train/                |             |
# |    entropy_loss       | -1.44       |
# |    explained_variance | -0.00243    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 499         |
# |    policy_loss        | -127        |
# |    reward             | -121.559845 |
# |    std                | 1.02        |
# |    value_loss         | 2.72e+04    |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1965      |
# |    iterations         | 600       |
# |    time_elapsed       | 1         |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -1.43     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | 8.24      |
# |    reward             | -4.100634 |
# |    std                | 1.01      |
# |    value_loss         | 200       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1990      |
# |    iterations         | 700       |
# |    time_elapsed       | 1         |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -1.43     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | -43.5     |
# |    reward             | -28.42499 |
# |    std                | 1.01      |
# |    value_loss         | 1.57e+03  |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 2003       |
# |    iterations         | 800        |
# |    time_elapsed       | 1          |
# |    total_timesteps    | 4000       |
# | train/                |            |
# |    entropy_loss       | -1.43      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 799        |
# |    policy_loss        | 83.9       |
# |    reward             | -278.33865 |
# |    std                | 1.02       |
# |    value_loss         | 1.82e+04   |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 2010       |
# |    iterations         | 900        |
# |    time_elapsed       | 2          |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -1.44      |
# |    explained_variance | -0.0429    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 899        |
# |    policy_loss        | 72         |
# |    reward             | -1.7820348 |
# |    std                | 1.02       |
# |    value_loss         | 4.87e+03   |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 2020        |
# |    iterations         | 1000        |
# |    time_elapsed       | 2           |
# |    total_timesteps    | 5000        |
# | train/                |             |
# |    entropy_loss       | -1.43       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 999         |
# |    policy_loss        | 579         |
# |    reward             | -101.077576 |
# |    std                | 1.01        |
# |    value_loss         | 9.81e+05    |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 2028       |
# |    iterations         | 1100       |
# |    time_elapsed       | 2          |
# |    total_timesteps    | 5500       |
# | train/                |            |
# |    entropy_loss       | -1.45      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1099       |
# |    policy_loss        | -17.2      |
# |    reward             | -85.288315 |
# |    std                | 1.03       |
# |    value_loss         | 762        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 2037      |
# |    iterations         | 1200      |
# |    time_elapsed       | 2         |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -1.44     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1199      |
# |    policy_loss        | -109      |
# |    reward             | 373.46957 |
# |    std                | 1.02      |
# |    value_loss         | 9.37e+03  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 2044      |
# |    iterations         | 1300      |
# |    time_elapsed       | 3         |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -1.44     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1299      |
# |    policy_loss        | -1.62e+03 |
# |    reward             | -79.73879 |
# |    std                | 1.02      |
# |    value_loss         | 2.03e+06  |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 2049       |
# |    iterations         | 1400       |
# |    time_elapsed       | 3          |
# |    total_timesteps    | 7000       |
# | train/                |            |
# |    entropy_loss       | -1.45      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1399       |
# |    policy_loss        | 139        |
# |    reward             | -31.949715 |
# |    std                | 1.03       |
# |    value_loss         | 1.52e+04   |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 2055       |
# |    iterations         | 1500       |
# |    time_elapsed       | 3          |
# |    total_timesteps    | 7500       |
# | train/                |            |
# |    entropy_loss       | -1.45      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1499       |
# |    policy_loss        | 1.08       |
# |    reward             | -2.3838098 |
# |    std                | 1.03       |
# |    value_loss         | 0.743      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 2062       |
# |    iterations         | 1600       |
# |    time_elapsed       | 3          |
# |    total_timesteps    | 8000       |
# | train/                |            |
# |    entropy_loss       | -1.45      |
# |    explained_variance | 0.00577    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1599       |
# |    policy_loss        | -24.5      |
# |    reward             | -2.2072272 |
# |    std                | 1.03       |
# |    value_loss         | 223        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 2067      |
# |    iterations         | 1700      |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -1.45     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | -24.9     |
# |    reward             | 1.0857984 |
# |    std                | 1.03      |
# |    value_loss         | 290       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 2070       |
# |    iterations         | 1800       |
# |    time_elapsed       | 4          |
# |    total_timesteps    | 9000       |
# | train/                |            |
# |    entropy_loss       | -1.44      |
# |    explained_variance | 0.000104   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1799       |
# |    policy_loss        | -422       |
# |    reward             | -276.42044 |
# |    std                | 1.02       |
# |    value_loss         | 1.78e+05   |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 2072        |
# |    iterations         | 1900        |
# |    time_elapsed       | 4           |
# |    total_timesteps    | 9500        |
# | train/                |             |
# |    entropy_loss       | -1.44       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1899        |
# |    policy_loss        | -3.21       |
# |    reward             | -0.29410622 |
# |    std                | 1.02        |
# |    value_loss         | 36          |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 2076      |
# |    iterations         | 2000      |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -1.45     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1999      |
# |    policy_loss        | 5.12      |
# |    reward             | 1.5954884 |
# |    std                | 1.03      |
# |    value_loss         | 16.2      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2080     |
# |    iterations         | 2100     |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 10500    |
# | train/                |          |
# |    entropy_loss       | -1.45    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | 83.3     |
# |    reward             | 91.63452 |
# |    std                | 1.03     |
# |    value_loss         | 2.79e+03 |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 2083       |
# |    iterations         | 2200       |
# |    time_elapsed       | 5          |
# |    total_timesteps    | 11000      |
# | train/                |            |
# |    entropy_loss       | -1.45      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2199       |
# |    policy_loss        | 168        |
# |    reward             | -29.583094 |
# |    std                | 1.03       |
# |    value_loss         | 3.25e+04   |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 2086       |
# |    iterations         | 2300       |
# |    time_elapsed       | 5          |
# |    total_timesteps    | 11500      |
# | train/                |            |
# |    entropy_loss       | -1.45      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2299       |
# |    policy_loss        | 1.63       |
# |    reward             | -4.5243406 |
# |    std                | 1.03       |
# |    value_loss         | 9.39       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 2089      |
# |    iterations         | 2400      |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 12000     |
# | train/                |           |
# |    entropy_loss       | -1.44     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2399      |
# |    policy_loss        | 54.8      |
# |    reward             | 1.8949263 |
# |    std                | 1.02      |
# |    value_loss         | 2.86e+03  |
# -------------------------------------
# day: 1352, episode: 10
# begin_total_asset: 100000.00
# end_total_asset: -2672163.53
# total_reward: -2772163.53
# total_cost: -97369.06
# total_trades: 394
# Sharpe: 0.454
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 2091      |
# |    iterations         | 2500      |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 12500     |
# | train/                |           |
# |    entropy_loss       | -1.44     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2499      |
# |    policy_loss        | -600      |
# |    reward             | 120.74718 |
# |    std                | 1.02      |
# |    value_loss         | 1.44e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 2089      |
# |    iterations         | 2600      |
# |    time_elapsed       | 6         |
# |    total_timesteps    | 13000     |
# | train/                |           |
# |    entropy_loss       | -1.44     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2599      |
# |    policy_loss        | 359       |
# |    reward             | -82.15838 |
# |    std                | 1.02      |
# |    value_loss         | 4.38e+04  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 2088      |
# |    iterations         | 2700      |
# |    time_elapsed       | 6         |
# |    total_timesteps    | 13500     |
# | train/                |           |
# |    entropy_loss       | -1.44     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2699      |
# |    policy_loss        | -212      |
# |    reward             | 7.5675607 |
# |    std                | 1.02      |
# |    value_loss         | 1.31e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 2089      |
# |    iterations         | 2800      |
# |    time_elapsed       | 6         |
# |    total_timesteps    | 14000     |
# | train/                |           |
# |    entropy_loss       | -1.44     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2799      |
# |    policy_loss        | -10.1     |
# |    reward             | -0.912808 |
# |    std                | 1.02      |
# |    value_loss         | 70.8      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 2090       |
# |    iterations         | 2900       |
# |    time_elapsed       | 6          |
# |    total_timesteps    | 14500      |
# | train/                |            |
# |    entropy_loss       | -1.42      |
# |    explained_variance | 0.0138     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2899       |
# |    policy_loss        | 11.8       |
# |    reward             | 11.9419565 |
# |    std                | 1          |
# |    value_loss         | 156        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 2092       |
# |    iterations         | 3000       |
# |    time_elapsed       | 7          |
# |    total_timesteps    | 15000      |
# | train/                |            |
# |    entropy_loss       | -1.43      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2999       |
# |    policy_loss        | 11.3       |
# |    reward             | -198.30243 |
# |    std                | 1.01       |
# |    value_loss         | 483        |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2093     |
# |    iterations         | 3100     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 15500    |
# | train/                |          |
# |    entropy_loss       | -1.43    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | -97      |
# |    reward             | -47.1511 |
# |    std                | 1.01     |
# |    value_loss         | 7.54e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2095     |
# |    iterations         | 3200     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -1.44    |
# |    explained_variance | 2.38e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | -365     |
# |    reward             | 223.1247 |
# |    std                | 1.02     |
# |    value_loss         | 3.04e+05 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 2095      |
# |    iterations         | 3300      |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 16500     |
# | train/                |           |
# |    entropy_loss       | -1.44     |
# |    explained_variance | 0.0888    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3299      |
# |    policy_loss        | -29.1     |
# |    reward             | 12.474439 |
# |    std                | 1.01      |
# |    value_loss         | 99        |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 2096       |
# |    iterations         | 3400       |
# |    time_elapsed       | 8          |
# |    total_timesteps    | 17000      |
# | train/                |            |
# |    entropy_loss       | -1.43      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3399       |
# |    policy_loss        | 2.87       |
# |    reward             | -1.7381243 |
# |    std                | 1.01       |
# |    value_loss         | 30         |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 2098       |
# |    iterations         | 3500       |
# |    time_elapsed       | 8          |
# |    total_timesteps    | 17500      |
# | train/                |            |
# |    entropy_loss       | -1.42      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3499       |
# |    policy_loss        | 19.8       |
# |    reward             | -3.1566672 |
# |    std                | 0.998      |
# |    value_loss         | 242        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 2099      |
# |    iterations         | 3600      |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -1.43     |
# |    explained_variance | 0.00479   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3599      |
# |    policy_loss        | -27.1     |
# |    reward             | -38.10463 |
# |    std                | 1.01      |
# |    value_loss         | 597       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 2100      |
# |    iterations         | 3700      |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 18500     |
# | train/                |           |
# |    entropy_loss       | -1.43     |
# |    explained_variance | 2.38e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3699      |
# |    policy_loss        | 1.01e+03  |
# |    reward             | 12.023933 |
# |    std                | 1.01      |
# |    value_loss         | 5.79e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 2100      |
# |    iterations         | 3800      |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 19000     |
# | train/                |           |
# |    entropy_loss       | -1.42     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3799      |
# |    policy_loss        | 67.8      |
# |    reward             | 13.128177 |
# |    std                | 1.01      |
# |    value_loss         | 1.77e+03  |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 2101       |
# |    iterations         | 3900       |
# |    time_elapsed       | 9          |
# |    total_timesteps    | 19500      |
# | train/                |            |
# |    entropy_loss       | -1.43      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3899       |
# |    policy_loss        | 746        |
# |    reward             | -48.809925 |
# |    std                | 1.01       |
# |    value_loss         | 5.89e+05   |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 2103      |
# |    iterations         | 4000      |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -1.43     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3999      |
# |    policy_loss        | -4.37e+03 |
# |    reward             | 1625.5172 |
# |    std                | 1.01      |
# |    value_loss         | 9.71e+06  |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 2103       |
# |    iterations         | 4100       |
# |    time_elapsed       | 9          |
# |    total_timesteps    | 20500      |
# | train/                |            |
# |    entropy_loss       | -1.44      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4099       |
# |    policy_loss        | 26.5       |
# |    reward             | -61.943916 |
# |    std                | 1.02       |
# |    value_loss         | 642        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 2103      |
# |    iterations         | 4200      |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 21000     |
# | train/                |           |
# |    entropy_loss       | -1.44     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4199      |
# |    policy_loss        | 286       |
# |    reward             | 36.893883 |
# |    std                | 1.02      |
# |    value_loss         | 4.74e+04  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 2104      |
# |    iterations         | 4300      |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 21500     |
# | train/                |           |
# |    entropy_loss       | -1.45     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4299      |
# |    policy_loss        | 61.5      |
# |    reward             | -599.0099 |
# |    std                | 1.03      |
# |    value_loss         | 4.12e+04  |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 2105       |
# |    iterations         | 4400       |
# |    time_elapsed       | 10         |
# |    total_timesteps    | 22000      |
# | train/                |            |
# |    entropy_loss       | -1.44      |
# |    explained_variance | -0.0358    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4399       |
# |    policy_loss        | -0.297     |
# |    reward             | -0.9228854 |
# |    std                | 1.02       |
# |    value_loss         | 34.6       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 2105      |
# |    iterations         | 4500      |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 22500     |
# | train/                |           |
# |    entropy_loss       | -1.45     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4499      |
# |    policy_loss        | -180      |
# |    reward             | -159.0537 |
# |    std                | 1.03      |
# |    value_loss         | 4.09e+04  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 2102      |
# |    iterations         | 4600      |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 23000     |
# | train/                |           |
# |    entropy_loss       | -1.45     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4599      |
# |    policy_loss        | 1.78      |
# |    reward             | 1.4955086 |
# |    std                | 1.03      |
# |    value_loss         | 260       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 2099      |
# |    iterations         | 4700      |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 23500     |
# | train/                |           |
# |    entropy_loss       | -1.45     |
# |    explained_variance | 0.00315   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4699      |
# |    policy_loss        | -172      |
# |    reward             | 63.490044 |
# |    std                | 1.04      |
# |    value_loss         | 2.41e+04  |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 2099       |
# |    iterations         | 4800       |
# |    time_elapsed       | 11         |
# |    total_timesteps    | 24000      |
# | train/                |            |
# |    entropy_loss       | -1.46      |
# |    explained_variance | -2.38e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4799       |
# |    policy_loss        | -796       |
# |    reward             | -241.89952 |
# |    std                | 1.04       |
# |    value_loss         | 3.28e+05   |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 2099      |
# |    iterations         | 4900      |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 24500     |
# | train/                |           |
# |    entropy_loss       | -1.44     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4899      |
# |    policy_loss        | -29.2     |
# |    reward             | 15.248306 |
# |    std                | 1.02      |
# |    value_loss         | 1.53e+03  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2099     |
# |    iterations         | 5000     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 25000    |
# | train/                |          |
# |    entropy_loss       | -1.45    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4999     |
# |    policy_loss        | 199      |
# |    reward             | 405.0657 |
# |    std                | 1.03     |
# |    value_loss         | 2.61e+04 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 2099      |
# |    iterations         | 5100      |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 25500     |
# | train/                |           |
# |    entropy_loss       | -1.44     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5099      |
# |    policy_loss        | 7.4e+03   |
# |    reward             | 682.98267 |
# |    std                | 1.02      |
# |    value_loss         | 2.87e+07  |
# -------------------------------------
# day: 1352, episode: 20
# begin_total_asset: 100000.00
# end_total_asset: -45645782.94
# total_reward: -45745782.94
# total_cost: -514992.52
# total_trades: 1352
# Sharpe: -0.471
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 2099      |
# |    iterations         | 5200      |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 26000     |
# | train/                |           |
# |    entropy_loss       | -1.45     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5199      |
# |    policy_loss        | 23.8      |
# |    reward             | 1.7881283 |
# |    std                | 1.03      |
# |    value_loss         | 622       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 2100      |
# |    iterations         | 5300      |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 26500     |
# | train/                |           |
# |    entropy_loss       | -1.45     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5299      |
# |    policy_loss        | 13.6      |
# |    reward             | 66.252625 |
# |    std                | 1.03      |
# |    value_loss         | 333       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 2100       |
# |    iterations         | 5400       |
# |    time_elapsed       | 12         |
# |    total_timesteps    | 27000      |
# | train/                |            |
# |    entropy_loss       | -1.46      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5399       |
# |    policy_loss        | 139        |
# |    reward             | -60.626842 |
# |    std                | 1.04       |
# |    value_loss         | 9.49e+03   |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 2096      |
# |    iterations         | 5500      |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 27500     |
# | train/                |           |
# |    entropy_loss       | -1.46     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5499      |
# |    policy_loss        | 817       |
# |    reward             | 245.23016 |
# |    std                | 1.04      |
# |    value_loss         | 5.18e+05  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2096     |
# |    iterations         | 5600     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -1.45    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5599     |
# |    policy_loss        | 0.144    |
# |    reward             | 53.55287 |
# |    std                | 1.03     |
# |    value_loss         | 4.97e+05 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 2097      |
# |    iterations         | 5700      |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 28500     |
# | train/                |           |
# |    entropy_loss       | -1.45     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5699      |
# |    policy_loss        | 65.6      |
# |    reward             | -69.10389 |
# |    std                | 1.04      |
# |    value_loss         | 7.62e+03  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 2096      |
# |    iterations         | 5800      |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 29000     |
# | train/                |           |
# |    entropy_loss       | -1.46     |
# |    explained_variance | -0.000759 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5799      |
# |    policy_loss        | 68.7      |
# |    reward             | 73.64083  |
# |    std                | 1.04      |
# |    value_loss         | 2.19e+03  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2093     |
# |    iterations         | 5900     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 29500    |
# | train/                |          |
# |    entropy_loss       | -1.46    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5899     |
# |    policy_loss        | 702      |
# |    reward             | 56.53771 |
# |    std                | 1.04     |
# |    value_loss         | 6.58e+05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2093     |
# |    iterations         | 6000     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -1.46    |
# |    explained_variance | -31      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5999     |
# |    policy_loss        | 12.9     |
# |    reward             | 8.569241 |
# |    std                | 1.04     |
# |    value_loss         | 172      |
# ------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 2094         |
# |    iterations         | 6100         |
# |    time_elapsed       | 14           |
# |    total_timesteps    | 30500        |
# | train/                |              |
# |    entropy_loss       | -1.46        |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 6099         |
# |    policy_loss        | 0.274        |
# |    reward             | -0.005058914 |
# |    std                | 1.04         |
# |    value_loss         | 0.0409       |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 2094        |
# |    iterations         | 6200        |
# |    time_elapsed       | 14          |
# |    total_timesteps    | 31000       |
# | train/                |             |
# |    entropy_loss       | -1.45       |
# |    explained_variance | 0.185       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 6199        |
# |    policy_loss        | -3.97       |
# |    reward             | -0.44678965 |
# |    std                | 1.03        |
# |    value_loss         | 4.59        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 2092      |
# |    iterations         | 6300      |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 31500     |
# | train/                |           |
# |    entropy_loss       | -1.46     |
# |    explained_variance | 0.119     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6299      |
# |    policy_loss        | 1.74      |
# |    reward             | 5.3606324 |
# |    std                | 1.04      |
# |    value_loss         | 1.83      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 2093      |
# |    iterations         | 6400      |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 32000     |
# | train/                |           |
# |    entropy_loss       | -1.47     |
# |    explained_variance | 0.00187   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6399      |
# |    policy_loss        | -230      |
# |    reward             | 28.261318 |
# |    std                | 1.05      |
# |    value_loss         | 5.76e+04  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 2094      |
# |    iterations         | 6500      |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 32500     |
# | train/                |           |
# |    entropy_loss       | -1.46     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6499      |
# |    policy_loss        | 3.93      |
# |    reward             | 7.4926386 |
# |    std                | 1.04      |
# |    value_loss         | 28.4      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 2094      |
# |    iterations         | 6600      |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 33000     |
# | train/                |           |
# |    entropy_loss       | -1.45     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6599      |
# |    policy_loss        | -79.7     |
# |    reward             | -610.7293 |
# |    std                | 1.03      |
# |    value_loss         | 5.61e+03  |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 2093       |
# |    iterations         | 6700       |
# |    time_elapsed       | 16         |
# |    total_timesteps    | 33500      |
# | train/                |            |
# |    entropy_loss       | -1.45      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6699       |
# |    policy_loss        | -3.52e+03  |
# |    reward             | -273.90515 |
# |    std                | 1.03       |
# |    value_loss         | 7.91e+06   |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 2093      |
# |    iterations         | 6800      |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 34000     |
# | train/                |           |
# |    entropy_loss       | -1.44     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6799      |
# |    policy_loss        | 239       |
# |    reward             | 52.773964 |
# |    std                | 1.03      |
# |    value_loss         | 1.15e+04  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 2093      |
# |    iterations         | 6900      |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 34500     |
# | train/                |           |
# |    entropy_loss       | -1.43     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6899      |
# |    policy_loss        | 76.5      |
# |    reward             | 13.839243 |
# |    std                | 1.01      |
# |    value_loss         | 2.45e+04  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 2093      |
# |    iterations         | 7000      |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 35000     |
# | train/                |           |
# |    entropy_loss       | -1.42     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6999      |
# |    policy_loss        | -2.02e+03 |
# |    reward             | 282.12167 |
# |    std                | 0.997     |
# |    value_loss         | 3.75e+06  |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 2093        |
# |    iterations         | 7100        |
# |    time_elapsed       | 16          |
# |    total_timesteps    | 35500       |
# | train/                |             |
# |    entropy_loss       | -1.41       |
# |    explained_variance | 0.17        |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 7099        |
# |    policy_loss        | 42.7        |
# |    reward             | -0.35230336 |
# |    std                | 0.989       |
# |    value_loss         | 962         |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 2094       |
# |    iterations         | 7200       |
# |    time_elapsed       | 17         |
# |    total_timesteps    | 36000      |
# | train/                |            |
# |    entropy_loss       | -1.41      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7199       |
# |    policy_loss        | -23.7      |
# |    reward             | -23.390528 |
# |    std                | 0.988      |
# |    value_loss         | 452        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 2094      |
# |    iterations         | 7300      |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 36500     |
# | train/                |           |
# |    entropy_loss       | -1.41     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7299      |
# |    policy_loss        | 129       |
# |    reward             | 5.7687516 |
# |    std                | 0.991     |
# |    value_loss         | 1.18e+04  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 2094      |
# |    iterations         | 7400      |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 37000     |
# | train/                |           |
# |    entropy_loss       | -1.41     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7399      |
# |    policy_loss        | -97       |
# |    reward             | 64.947655 |
# |    std                | 0.988     |
# |    value_loss         | 3.34e+03  |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 2095       |
# |    iterations         | 7500       |
# |    time_elapsed       | 17         |
# |    total_timesteps    | 37500      |
# | train/                |            |
# |    entropy_loss       | -1.41      |
# |    explained_variance | 0.0298     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7499       |
# |    policy_loss        | 44.1       |
# |    reward             | -35.565975 |
# |    std                | 0.996      |
# |    value_loss         | 3.06e+03   |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 2095      |
# |    iterations         | 7600      |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 38000     |
# | train/                |           |
# |    entropy_loss       | -1.41     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7599      |
# |    policy_loss        | 0.548     |
# |    reward             | 0.4932504 |
# |    std                | 0.988     |
# |    value_loss         | 0.653     |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 2096        |
# |    iterations         | 7700        |
# |    time_elapsed       | 18          |
# |    total_timesteps    | 38500       |
# | train/                |             |
# |    entropy_loss       | -1.42       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 7699        |
# |    policy_loss        | 0.836       |
# |    reward             | -0.42700145 |
# |    std                | 1           |
# |    value_loss         | 0.677       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 2096       |
# |    iterations         | 7800       |
# |    time_elapsed       | 18         |
# |    total_timesteps    | 39000      |
# | train/                |            |
# |    entropy_loss       | -1.43      |
# |    explained_variance | 0.349      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7799       |
# |    policy_loss        | -0.651     |
# |    reward             | -0.7316317 |
# |    std                | 1.01       |
# |    value_loss         | 1.92       |
# --------------------------------------
# day: 1352, episode: 30
# begin_total_asset: 100000.00
# end_total_asset: -327787.38
# total_reward: -427787.38
# total_cost: -2031.72
# total_trades: 23
# Sharpe: 0.060
# =================================
# --------------------------------------
# | time/                 |            |
# |    fps                | 2096       |
# |    iterations         | 7900       |
# |    time_elapsed       | 18         |
# |    total_timesteps    | 39500      |
# | train/                |            |
# |    entropy_loss       | -1.43      |
# |    explained_variance | 0.111      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7899       |
# |    policy_loss        | -41.1      |
# |    reward             | -30.119394 |
# |    std                | 1.01       |
# |    value_loss         | 1.46e+03   |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 2097       |
# |    iterations         | 8000       |
# |    time_elapsed       | 19         |
# |    total_timesteps    | 40000      |
# | train/                |            |
# |    entropy_loss       | -1.43      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7999       |
# |    policy_loss        | 32.3       |
# |    reward             | -16.172668 |
# |    std                | 1.01       |
# |    value_loss         | 1.2e+03    |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 2095      |
# |    iterations         | 8100      |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 40500     |
# | train/                |           |
# |    entropy_loss       | -1.43     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8099      |
# |    policy_loss        | 65        |
# |    reward             | 13.326755 |
# |    std                | 1.01      |
# |    value_loss         | 3.13e+03  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 2095      |
# |    iterations         | 8200      |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 41000     |
# | train/                |           |
# |    entropy_loss       | -1.42     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8199      |
# |    policy_loss        | 55.1      |
# |    reward             | 39.706413 |
# |    std                | 1         |
# |    value_loss         | 1.99e+03  |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 2095       |
# |    iterations         | 8300       |
# |    time_elapsed       | 19         |
# |    total_timesteps    | 41500      |
# | train/                |            |
# |    entropy_loss       | -1.41      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8299       |
# |    policy_loss        | -1.73e+03  |
# |    reward             | -22.324736 |
# |    std                | 0.992      |
# |    value_loss         | 1.34e+06   |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2096     |
# |    iterations         | 8400     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 42000    |
# | train/                |          |
# |    entropy_loss       | -1.42    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8399     |
# |    policy_loss        | 54       |
# |    reward             | 6.119619 |
# |    std                | 0.997    |
# |    value_loss         | 1.15e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2096     |
# |    iterations         | 8500     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 42500    |
# | train/                |          |
# |    entropy_loss       | -1.41    |
# |    explained_variance | 0.00422  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8499     |
# |    policy_loss        | -254     |
# |    reward             | -30.3929 |
# |    std                | 0.993    |
# |    value_loss         | 6.19e+04 |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 2096       |
# |    iterations         | 8600       |
# |    time_elapsed       | 20         |
# |    total_timesteps    | 43000      |
# | train/                |            |
# |    entropy_loss       | -1.41      |
# |    explained_variance | 0.00235    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8599       |
# |    policy_loss        | -22.7      |
# |    reward             | -344.03012 |
# |    std                | 0.989      |
# |    value_loss         | 2.94e+05   |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 2096       |
# |    iterations         | 8700       |
# |    time_elapsed       | 20         |
# |    total_timesteps    | 43500      |
# | train/                |            |
# |    entropy_loss       | -1.41      |
# |    explained_variance | -14.7      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8699       |
# |    policy_loss        | 5.62       |
# |    reward             | -15.542015 |
# |    std                | 0.987      |
# |    value_loss         | 84         |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 2097      |
# |    iterations         | 8800      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 44000     |
# | train/                |           |
# |    entropy_loss       | -1.42     |
# |    explained_variance | -1.7      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8799      |
# |    policy_loss        | 9.4       |
# |    reward             | -5.036543 |
# |    std                | 0.997     |
# |    value_loss         | 174       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 2097      |
# |    iterations         | 8900      |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 44500     |
# | train/                |           |
# |    entropy_loss       | -1.41     |
# |    explained_variance | 0.0648    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8899      |
# |    policy_loss        | -34.5     |
# |    reward             | 229.20459 |
# |    std                | 0.994     |
# |    value_loss         | 4.73e+03  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 2098      |
# |    iterations         | 9000      |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 45000     |
# | train/                |           |
# |    entropy_loss       | -1.4      |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8999      |
# |    policy_loss        | -0.369    |
# |    reward             | -45.78924 |
# |    std                | 0.984     |
# |    value_loss         | 133       |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2098     |
# |    iterations         | 9100     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 45500    |
# | train/                |          |
# |    entropy_loss       | -1.41    |
# |    explained_variance | 0.0281   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9099     |
# |    policy_loss        | -220     |
# |    reward             | -96.8734 |
# |    std                | 0.99     |
# |    value_loss         | 3.32e+04 |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 2098       |
# |    iterations         | 9200       |
# |    time_elapsed       | 21         |
# |    total_timesteps    | 46000      |
# | train/                |            |
# |    entropy_loss       | -1.42      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9199       |
# |    policy_loss        | 12.4       |
# |    reward             | -3.8602931 |
# |    std                | 0.999      |
# |    value_loss         | 600        |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2098     |
# |    iterations         | 9300     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 46500    |
# | train/                |          |
# |    entropy_loss       | -1.42    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9299     |
# |    policy_loss        | -24.5    |
# |    reward             | 6.286002 |
# |    std                | 0.999    |
# |    value_loss         | 547      |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 2098      |
# |    iterations         | 9400      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 47000     |
# | train/                |           |
# |    entropy_loss       | -1.42     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9399      |
# |    policy_loss        | -44.7     |
# |    reward             | -13.44711 |
# |    std                | 1         |
# |    value_loss         | 3.25e+03  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2099     |
# |    iterations         | 9500     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 47500    |
# | train/                |          |
# |    entropy_loss       | -1.42    |
# |    explained_variance | 1.79e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9499     |
# |    policy_loss        | -372     |
# |    reward             | 4.155244 |
# |    std                | 1        |
# |    value_loss         | 3.54e+04 |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 2099       |
# |    iterations         | 9600       |
# |    time_elapsed       | 22         |
# |    total_timesteps    | 48000      |
# | train/                |            |
# |    entropy_loss       | -1.43      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9599       |
# |    policy_loss        | 215        |
# |    reward             | -1951.5392 |
# |    std                | 1.01       |
# |    value_loss         | 2.93e+04   |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 2099      |
# |    iterations         | 9700      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 48500     |
# | train/                |           |
# |    entropy_loss       | -1.44     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9699      |
# |    policy_loss        | 4.38e+03  |
# |    reward             | -761.2452 |
# |    std                | 1.02      |
# |    value_loss         | 1e+07     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 2091      |
# |    iterations         | 9800      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 49000     |
# | train/                |           |
# |    entropy_loss       | -1.43     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9799      |
# |    policy_loss        | 36.3      |
# |    reward             | 127.45499 |
# |    std                | 1.01      |
# |    value_loss         | 842       |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2091     |
# |    iterations         | 9900     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 49500    |
# | train/                |          |
# |    entropy_loss       | -1.44    |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9899     |
# |    policy_loss        | -218     |
# |    reward             | 87.7554  |
# |    std                | 1.02     |
# |    value_loss         | 1.56e+04 |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 2092       |
# |    iterations         | 10000      |
# |    time_elapsed       | 23         |
# |    total_timesteps    | 50000      |
# | train/                |            |
# |    entropy_loss       | -1.44      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9999       |
# |    policy_loss        | 785        |
# |    reward             | -219.66136 |
# |    std                | 1.02       |
# |    value_loss         | 2.89e+05   |
# --------------------------------------

# %%
trained_a2c.save(TRAINED_MODEL_DIR + "/agent_a2c") if if_using_a2c else None

# %% [markdown]
# ### Agent 2: DDPG

# %%
agent = DRLAgent(env = env_train)
model_ddpg = agent.get_model("ddpg")

if if_using_ddpg:
  # set up logger
  tmp_path = RESULTS_DIR + '/ddpg'
  new_logger_ddpg = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_ddpg.set_logger(new_logger_ddpg)
# Out:
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.001}
# Using cpu device
# Logging to results/ddpg

# %%
trained_ddpg = agent.train_model(model=model_ddpg, 
                             tb_log_name='ddpg',
                             total_timesteps=50000) if if_using_ddpg else None
# Out:
# day: 1352, episode: 40
# begin_total_asset: 100000.00
# end_total_asset: 399214.67
# total_reward: 299214.67
# total_cost: 199.60
# total_trades: 1352
# Sharpe: 0.726
# =================================
# ------------------------------------
# | time/              |             |
# |    episodes        | 4           |
# |    fps             | 380         |
# |    time_elapsed    | 14          |
# |    total_timesteps | 5412        |
# | train/             |             |
# |    actor_loss      | 1.12e+03    |
# |    critic_loss     | 8.18e+03    |
# |    learning_rate   | 0.001       |
# |    n_updates       | 4059        |
# |    reward          | -0.06604568 |
# ------------------------------------
# ------------------------------------
# | time/              |             |
# |    episodes        | 8           |
# |    fps             | 333         |
# |    time_elapsed    | 32          |
# |    total_timesteps | 10824       |
# | train/             |             |
# |    actor_loss      | 839         |
# |    critic_loss     | 3.58e+03    |
# |    learning_rate   | 0.001       |
# |    n_updates       | 9471        |
# |    reward          | -0.06604568 |
# ------------------------------------
# day: 1352, episode: 50
# begin_total_asset: 100000.00
# end_total_asset: 399214.67
# total_reward: 299214.67
# total_cost: 199.60
# total_trades: 1352
# Sharpe: 0.726
# =================================
# ------------------------------------
# | time/              |             |
# |    episodes        | 12          |
# |    fps             | 307         |
# |    time_elapsed    | 52          |
# |    total_timesteps | 16236       |
# | train/             |             |
# |    actor_loss      | 594         |
# |    critic_loss     | 1.91e+03    |
# |    learning_rate   | 0.001       |
# |    n_updates       | 14883       |
# |    reward          | -0.06604568 |
# ------------------------------------
# ------------------------------------
# | time/              |             |
# |    episodes        | 16          |
# |    fps             | 287         |
# |    time_elapsed    | 75          |
# |    total_timesteps | 21648       |
# | train/             |             |
# |    actor_loss      | 428         |
# |    critic_loss     | 1.03e+03    |
# |    learning_rate   | 0.001       |
# |    n_updates       | 20295       |
# |    reward          | -0.06604568 |
# ------------------------------------
# ------------------------------------
# | time/              |             |
# |    episodes        | 20          |
# |    fps             | 281         |
# |    time_elapsed    | 95          |
# |    total_timesteps | 27060       |
# | train/             |             |
# |    actor_loss      | 324         |
# |    critic_loss     | 732         |
# |    learning_rate   | 0.001       |
# |    n_updates       | 25707       |
# |    reward          | -0.06604568 |
# ------------------------------------
# day: 1352, episode: 60
# begin_total_asset: 100000.00
# end_total_asset: 399214.67
# total_reward: 299214.67
# total_cost: 199.60
# total_trades: 1352
# Sharpe: 0.726
# =================================
# ------------------------------------
# | time/              |             |
# |    episodes        | 24          |
# |    fps             | 284         |
# |    time_elapsed    | 114         |
# |    total_timesteps | 32472       |
# | train/             |             |
# |    actor_loss      | 245         |
# |    critic_loss     | 797         |
# |    learning_rate   | 0.001       |
# |    n_updates       | 31119       |
# |    reward          | -0.06604568 |
# ------------------------------------
# ------------------------------------
# | time/              |             |
# |    episodes        | 28          |
# |    fps             | 282         |
# |    time_elapsed    | 134         |
# |    total_timesteps | 37884       |
# | train/             |             |
# |    actor_loss      | 187         |
# |    critic_loss     | 208         |
# |    learning_rate   | 0.001       |
# |    n_updates       | 36531       |
# |    reward          | -0.06604568 |
# ------------------------------------
# day: 1352, episode: 70
# begin_total_asset: 100000.00
# end_total_asset: 399214.67
# total_reward: 299214.67
# total_cost: 199.60
# total_trades: 1352
# Sharpe: 0.726
# =================================
# ------------------------------------
# | time/              |             |
# |    episodes        | 32          |
# |    fps             | 283         |
# |    time_elapsed    | 152         |
# |    total_timesteps | 43296       |
# | train/             |             |
# |    actor_loss      | 127         |
# |    critic_loss     | 45.1        |
# |    learning_rate   | 0.001       |
# |    n_updates       | 41943       |
# |    reward          | -0.06604568 |
# ------------------------------------
# ------------------------------------
# | time/              |             |
# |    episodes        | 36          |
# |    fps             | 284         |
# |    time_elapsed    | 171         |
# |    total_timesteps | 48708       |
# | train/             |             |
# |    actor_loss      | 93.9        |
# |    critic_loss     | 12.7        |
# |    learning_rate   | 0.001       |
# |    n_updates       | 47355       |
# |    reward          | -0.06604568 |
# ------------------------------------

# %%
trained_ddpg.save(TRAINED_MODEL_DIR + "/agent_ddpg") if if_using_ddpg else None

# %% [markdown]
# ### Agent 3: PPO

# %%
agent = DRLAgent(env = env_train)
PPO_PARAMS = {
    "n_steps": 2048,
    "ent_coef": 0.01,
    "learning_rate": 0.00025,
    "batch_size": 128,
}
model_ppo = agent.get_model("ppo",model_kwargs = PPO_PARAMS)

if if_using_ppo:
  # set up logger
  tmp_path = RESULTS_DIR + '/ppo'
  new_logger_ppo = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_ppo.set_logger(new_logger_ppo)
# Out:
# {'n_steps': 2048, 'ent_coef': 0.01, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to results/ppo

# %%
trained_ppo = agent.train_model(model=model_ppo, 
                             tb_log_name='ppo',
                             total_timesteps=50000) if if_using_ppo else None
# Out:
# ----------------------------------
# | time/              |           |
# |    fps             | 3236      |
# |    iterations      | 1         |
# |    time_elapsed    | 0         |
# |    total_timesteps | 2048      |
# | train/             |           |
# |    reward          | 0.3659677 |
# ----------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2898         |
# |    iterations           | 2            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0040192436 |
# |    clip_fraction        | 0.0438       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.000495     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 209          |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00437     |
# |    reward               | -0.013266441 |
# |    std                  | 0.995        |
# |    value_loss           | 342          |
# ------------------------------------------
# day: 1352, episode: 80
# begin_total_asset: 100000.00
# end_total_asset: 444987.60
# total_reward: 344987.60
# total_cost: -359859.99
# total_trades: 1352
# Sharpe: 0.961
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2837         |
# |    iterations           | 3            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0022615558 |
# |    clip_fraction        | 0.014        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.00176     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 165          |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00162     |
# |    reward               | -0.34741178  |
# |    std                  | 1            |
# |    value_loss           | 455          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2809         |
# |    iterations           | 4            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0018883423 |
# |    clip_fraction        | 0.0101       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.000668    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 49.4         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.000648    |
# |    reward               | 2.1868773    |
# |    std                  | 1            |
# |    value_loss           | 117          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2794        |
# |    iterations           | 5           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.002382169 |
# |    clip_fraction        | 0.00493     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.00162     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 476         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00158    |
# |    reward               | -1.1817522  |
# |    std                  | 1           |
# |    value_loss           | 1.14e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2779        |
# |    iterations           | 6           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.005452223 |
# |    clip_fraction        | 0.0387      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.00343     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 52.7        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00228    |
# |    reward               | -0.4145223  |
# |    std                  | 0.998       |
# |    value_loss           | 112         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2766         |
# |    iterations           | 7            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0035140319 |
# |    clip_fraction        | 0.0129       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.00291      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 331          |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00176     |
# |    reward               | 0.42559978   |
# |    std                  | 1            |
# |    value_loss           | 590          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2762         |
# |    iterations           | 8            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0002687661 |
# |    clip_fraction        | 0.000146     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.00121     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 70.2         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.000183    |
# |    reward               | -0.071768604 |
# |    std                  | 1.01         |
# |    value_loss           | 131          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2759          |
# |    iterations           | 9             |
# |    time_elapsed         | 6             |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 0.00034575874 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.43         |
# |    explained_variance   | 0.00284       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 130           |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -1.89e-05     |
# |    reward               | 6.2602344     |
# |    std                  | 1.01          |
# |    value_loss           | 232           |
# -------------------------------------------
# day: 1352, episode: 90
# begin_total_asset: 100000.00
# end_total_asset: 767726.24
# total_reward: 667726.24
# total_cost: -351639.92
# total_trades: 1352
# Sharpe: 0.876
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2753        |
# |    iterations           | 10          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.004808042 |
# |    clip_fraction        | 0.037       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.00636     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 93.2        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00165    |
# |    reward               | 0.760816    |
# |    std                  | 1.01        |
# |    value_loss           | 217         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2750         |
# |    iterations           | 11           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0028350125 |
# |    clip_fraction        | 0.00176      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.00143      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 279          |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -7.31e-05    |
# |    reward               | 15.996671    |
# |    std                  | 1.01         |
# |    value_loss           | 816          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2748         |
# |    iterations           | 12           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0057410044 |
# |    clip_fraction        | 0.0222       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.00663      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 74.7         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.0024      |
# |    reward               | 0.28987792   |
# |    std                  | 1.01         |
# |    value_loss           | 181          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2745         |
# |    iterations           | 13           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0011108986 |
# |    clip_fraction        | 0.00278      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.00264      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 186          |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.000257    |
# |    reward               | 11.7477255   |
# |    std                  | 1.02         |
# |    value_loss           | 373          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2730         |
# |    iterations           | 14           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0027911877 |
# |    clip_fraction        | 0.0176       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.00808      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 124          |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00134     |
# |    reward               | 0.7495189    |
# |    std                  | 1.03         |
# |    value_loss           | 295          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2687        |
# |    iterations           | 15          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.004910953 |
# |    clip_fraction        | 0.0412      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.00157     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 239         |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0034     |
# |    reward               | 9.839766    |
# |    std                  | 1.03        |
# |    value_loss           | 475         |
# -----------------------------------------
# day: 1352, episode: 100
# begin_total_asset: 100000.00
# end_total_asset: 521034.95
# total_reward: 421034.95
# total_cost: -273058.54
# total_trades: 1352
# Sharpe: 0.807
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2690         |
# |    iterations           | 16           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0061301747 |
# |    clip_fraction        | 0.0366       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.45        |
# |    explained_variance   | 0.0155       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 264          |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00374     |
# |    reward               | -0.32214636  |
# |    std                  | 1.03         |
# |    value_loss           | 437          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2693         |
# |    iterations           | 17           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0021462434 |
# |    clip_fraction        | 0.0112       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.0104       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 220          |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00137     |
# |    reward               | 13.430461    |
# |    std                  | 1.02         |
# |    value_loss           | 341          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2696         |
# |    iterations           | 18           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0057353526 |
# |    clip_fraction        | 0.0432       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.0246       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 278          |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.0014      |
# |    reward               | -0.32185346  |
# |    std                  | 1.01         |
# |    value_loss           | 462          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2699        |
# |    iterations           | 19          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.0054374   |
# |    clip_fraction        | 0.0562      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.0133      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 164         |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00345    |
# |    reward               | -0.97003424 |
# |    std                  | 1.02        |
# |    value_loss           | 333         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2701         |
# |    iterations           | 20           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0035905836 |
# |    clip_fraction        | 0.0174       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.0214       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 215          |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00178     |
# |    reward               | -0.017868416 |
# |    std                  | 1.02         |
# |    value_loss           | 340          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2703         |
# |    iterations           | 21           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0017695813 |
# |    clip_fraction        | 0.00718      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | -0.00793     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 97.2         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.000743    |
# |    reward               | -3.0298443   |
# |    std                  | 1.02         |
# |    value_loss           | 176          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2705         |
# |    iterations           | 22           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0014814511 |
# |    clip_fraction        | 0.00156      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.45        |
# |    explained_variance   | 0.00916      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 219          |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.000485    |
# |    reward               | 4.779916     |
# |    std                  | 1.03         |
# |    value_loss           | 360          |
# ------------------------------------------
# day: 1352, episode: 110
# begin_total_asset: 100000.00
# end_total_asset: 967823.03
# total_reward: 867823.03
# total_cost: -311470.44
# total_trades: 1350
# Sharpe: 0.929
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2707         |
# |    iterations           | 23           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0026381111 |
# |    clip_fraction        | 0.0213       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.45        |
# |    explained_variance   | 0.0178       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 136          |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00093     |
# |    reward               | 0.27392077   |
# |    std                  | 1.02         |
# |    value_loss           | 254          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2708         |
# |    iterations           | 24           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0009455685 |
# |    clip_fraction        | 0.00327      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.45        |
# |    explained_variance   | 0.0022       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 202          |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.000726    |
# |    reward               | 0.3950836    |
# |    std                  | 1.04         |
# |    value_loss           | 518          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2710        |
# |    iterations           | 25          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.009010121 |
# |    clip_fraction        | 0.0555      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.46       |
# |    explained_variance   | 0.00458     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 253         |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00324    |
# |    reward               | 3.002123    |
# |    std                  | 1.04        |
# |    value_loss           | 309         |
# -----------------------------------------

# %%
trained_ppo.save(TRAINED_MODEL_DIR + "/agent_ppo") if if_using_ppo else None

# %% [markdown]
# ### Agent 4: TD3

# %%
agent = DRLAgent(env = env_train)
TD3_PARAMS = {"batch_size": 100, 
              "buffer_size": 1000000, 
              "learning_rate": 0.001}

model_td3 = agent.get_model("td3",model_kwargs = TD3_PARAMS)

if if_using_td3:
  # set up logger
  tmp_path = RESULTS_DIR + '/td3'
  new_logger_td3 = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_td3.set_logger(new_logger_td3)
# Out:
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device
# Logging to results/td3

# %%
trained_td3 = agent.train_model(model=model_td3, 
                             tb_log_name='td3',
                             total_timesteps=50000) if if_using_td3 else None
# Out:
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 396       |
# |    time_elapsed    | 13        |
# |    total_timesteps | 5412      |
# | train/             |           |
# |    actor_loss      | 1.83e+06  |
# |    critic_loss     | 8.52e+10  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 4059      |
# |    reward          | -34.42119 |
# ----------------------------------
# day: 1352, episode: 120
# begin_total_asset: 100000.00
# end_total_asset: -39404682.96
# total_reward: -39504682.96
# total_cost: -496094.86
# total_trades: 1352
# Sharpe: -0.869
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 345       |
# |    time_elapsed    | 31        |
# |    total_timesteps | 10824     |
# | train/             |           |
# |    actor_loss      | 2e+06     |
# |    critic_loss     | 6.36e+10  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 9471      |
# |    reward          | -34.42119 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 329       |
# |    time_elapsed    | 49        |
# |    total_timesteps | 16236     |
# | train/             |           |
# |    actor_loss      | 1.65e+06  |
# |    critic_loss     | 3.47e+10  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 14883     |
# |    reward          | -34.42119 |
# ----------------------------------
# day: 1352, episode: 130
# begin_total_asset: 100000.00
# end_total_asset: -39404682.96
# total_reward: -39504682.96
# total_cost: -496094.86
# total_trades: 1352
# Sharpe: -0.869
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 325       |
# |    time_elapsed    | 66        |
# |    total_timesteps | 21648     |
# | train/             |           |
# |    actor_loss      | 1.43e+06  |
# |    critic_loss     | 2.45e+10  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 20295     |
# |    reward          | -34.42119 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 322       |
# |    time_elapsed    | 83        |
# |    total_timesteps | 27060     |
# | train/             |           |
# |    actor_loss      | 1.23e+06  |
# |    critic_loss     | 1.97e+10  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 25707     |
# |    reward          | -34.42119 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 24        |
# |    fps             | 320       |
# |    time_elapsed    | 101       |
# |    total_timesteps | 32472     |
# | train/             |           |
# |    actor_loss      | 1.07e+06  |
# |    critic_loss     | 1.34e+10  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 31119     |
# |    reward          | -34.42119 |
# ----------------------------------
# day: 1352, episode: 140
# begin_total_asset: 100000.00
# end_total_asset: -39404682.96
# total_reward: -39504682.96
# total_cost: -496094.86
# total_trades: 1352
# Sharpe: -0.869
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 28        |
# |    fps             | 319       |
# |    time_elapsed    | 118       |
# |    total_timesteps | 37884     |
# | train/             |           |
# |    actor_loss      | 1.05e+06  |
# |    critic_loss     | 1.03e+10  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 36531     |
# |    reward          | -34.42119 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 32        |
# |    fps             | 318       |
# |    time_elapsed    | 136       |
# |    total_timesteps | 43296     |
# | train/             |           |
# |    actor_loss      | 9.27e+05  |
# |    critic_loss     | 1.04e+10  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 41943     |
# |    reward          | -34.42119 |
# ----------------------------------
# day: 1352, episode: 150
# begin_total_asset: 100000.00
# end_total_asset: -39404682.96
# total_reward: -39504682.96
# total_cost: -496094.86
# total_trades: 1352
# Sharpe: -0.869
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 36        |
# |    fps             | 317       |
# |    time_elapsed    | 153       |
# |    total_timesteps | 48708     |
# | train/             |           |
# |    actor_loss      | 8.33e+05  |
# |    critic_loss     | 6.67e+09  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 47355     |
# |    reward          | -34.42119 |
# ----------------------------------

# %%
trained_td3.save(TRAINED_MODEL_DIR + "/agent_td3") if if_using_td3 else None

# %% [markdown]
# ### Agent 5: SAC

# %%
agent = DRLAgent(env = env_train)
SAC_PARAMS = {
    "batch_size": 128,
    "buffer_size": 100000,
    "learning_rate": 0.0001,
#     "learning_starts": 100,
    "ent_coef": "auto_0.1",
}

model_sac = agent.get_model("sac",model_kwargs = SAC_PARAMS)

if if_using_sac:
  # set up logger
  tmp_path = RESULTS_DIR + '/sac'
  new_logger_sac = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_sac.set_logger(new_logger_sac)
# Out:
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.0001, 'ent_coef': 'auto_0.1'}
# Using cpu device
# Logging to results/sac

# %%
trained_sac = agent.train_model(model=model_sac, 
                             tb_log_name='sac',
                             total_timesteps=70000) if if_using_sac else None
# Out:
# ---------------------------------
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 238      |
# |    time_elapsed    | 22       |
# |    total_timesteps | 5412     |
# | train/             |          |
# |    actor_loss      | 1.53e+04 |
# |    critic_loss     | 3.59e+08 |
# |    ent_coef        | 0.168    |
# |    ent_coef_loss   | 16.7     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 5311     |
# |    reward          | 0.0      |
# ---------------------------------
# day: 1352, episode: 160
# begin_total_asset: 100000.00
# end_total_asset: 100000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 236      |
# |    time_elapsed    | 45       |
# |    total_timesteps | 10824    |
# | train/             |          |
# |    actor_loss      | 3.77e+03 |
# |    critic_loss     | 4.77e+05 |
# |    ent_coef        | 0.288    |
# |    ent_coef_loss   | 11.7     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 10723    |
# |    reward          | 0.0      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 236      |
# |    time_elapsed    | 68       |
# |    total_timesteps | 16236    |
# | train/             |          |
# |    actor_loss      | 4.52e+03 |
# |    critic_loss     | 1.47e+07 |
# |    ent_coef        | 0.494    |
# |    ent_coef_loss   | 6.6      |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 16135    |
# |    reward          | 0.0      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 236      |
# |    time_elapsed    | 91       |
# |    total_timesteps | 21648    |
# | train/             |          |
# |    actor_loss      | 1.85e+03 |
# |    critic_loss     | 2.52e+05 |
# |    ent_coef        | 0.849    |
# |    ent_coef_loss   | 1.54     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 21547    |
# |    reward          | 0.0      |
# ---------------------------------
# day: 1352, episode: 170
# begin_total_asset: 100000.00
# end_total_asset: 100000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 236      |
# |    time_elapsed    | 114      |
# |    total_timesteps | 27060    |
# | train/             |          |
# |    actor_loss      | 2.72e+03 |
# |    critic_loss     | 6.87e+05 |
# |    ent_coef        | 1.46     |
# |    ent_coef_loss   | -3.54    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 26959    |
# |    reward          | 0.0      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 236      |
# |    time_elapsed    | 137      |
# |    total_timesteps | 32472    |
# | train/             |          |
# |    actor_loss      | 2.48e+03 |
# |    critic_loss     | 9.56e+05 |
# |    ent_coef        | 2.51     |
# |    ent_coef_loss   | -8.71    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 32371    |
# |    reward          | 0.0      |
# ---------------------------------
# day: 1352, episode: 180
# begin_total_asset: 100000.00
# end_total_asset: 100000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 232      |
# |    time_elapsed    | 162      |
# |    total_timesteps | 37884    |
# | train/             |          |
# |    actor_loss      | 6.14e+03 |
# |    critic_loss     | 3.3e+07  |
# |    ent_coef        | 4.31     |
# |    ent_coef_loss   | -13.8    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 37783    |
# |    reward          | 0.0      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 229      |
# |    time_elapsed    | 188      |
# |    total_timesteps | 43296    |
# | train/             |          |
# |    actor_loss      | 7.14e+03 |
# |    critic_loss     | 1.22e+07 |
# |    ent_coef        | 7.4      |
# |    ent_coef_loss   | -18.8    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 43195    |
# |    reward          | 0.0      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 229      |
# |    time_elapsed    | 212      |
# |    total_timesteps | 48708    |
# | train/             |          |
# |    actor_loss      | 5.33e+03 |
# |    critic_loss     | 3.5e+04  |
# |    ent_coef        | 12.7     |
# |    ent_coef_loss   | -24      |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 48607    |
# |    reward          | 0.0      |
# ---------------------------------
# day: 1352, episode: 190
# begin_total_asset: 100000.00
# end_total_asset: 100000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 229      |
# |    time_elapsed    | 235      |
# |    total_timesteps | 54120    |
# | train/             |          |
# |    actor_loss      | 1.07e+04 |
# |    critic_loss     | 1.01e+06 |
# |    ent_coef        | 21.8     |
# |    ent_coef_loss   | -29.2    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 54019    |
# |    reward          | 0.0      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 229      |
# |    time_elapsed    | 258      |
# |    total_timesteps | 59532    |
# | train/             |          |
# |    actor_loss      | 1.44e+04 |
# |    critic_loss     | 2.88e+04 |
# |    ent_coef        | 37.5     |
# |    ent_coef_loss   | -34.1    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 59431    |
# |    reward          | 0.0      |
# ---------------------------------
# day: 1352, episode: 200
# begin_total_asset: 100000.00
# end_total_asset: 100000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 230      |
# |    time_elapsed    | 282      |
# |    total_timesteps | 64944    |
# | train/             |          |
# |    actor_loss      | 2.44e+04 |
# |    critic_loss     | 3.29e+05 |
# |    ent_coef        | 64.5     |
# |    ent_coef_loss   | -39.3    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 64843    |
# |    reward          | 0.0      |
# ---------------------------------

# %%
trained_sac.save(TRAINED_MODEL_DIR + "/agent_sac") if if_using_sac else None

# %% [markdown]
# ### In-sample Performance
# Assume that the initial capital is $1,000,000.

# %% [markdown]
# ### Trading (Out-of-sample Performance)
# We update periodically in order to take full advantage of the data, e.g., retrain quarterly, monthly or weekly. We also tune the parameters along the way, in this notebook we use the in-sample data from 2009-01 to 2020-07 to tune the parameters once, so there is some alpha decay here as the length of trade date extends.
#
# Numerous hyperparameters – e.g. the learning rate, the total number of samples to train on – influence the learning process and are usually determined by testing some variations.
#
# The Env
# https://github.com/AI4Finance-Foundation/FinRL/blob/master/finrl/meta/env_stock_trading/env_stocktrading.py

# %%
e_trade_gym = StockTradingEnv(df = trade, turbulence_threshold = 70,risk_indicator_col='vix', **env_kwargs)
# env_trade, obs_trade = e_trade_gym.get_sb_env()

# %%
from stable_baselines3 import A2C, DDPG, PPO, SAC, TD3

trained_a2c = A2C.load("trained_models/agent_a2c") if if_using_a2c else None
trained_ddpg = DDPG.load("trained_models/agent_ddpg") if if_using_ddpg else None
trained_ppo = PPO.load("trained_models/agent_ppo") if if_using_ppo else None
trained_td3 = TD3.load("trained_models/agent_td3") if if_using_td3 else None
trained_sac = SAC.load("trained_models/agent_sac") if if_using_sac else None

# %%
trained_model = trained_a2c
df_account_value_a2c, df_actions_a2c = DRLAgent.DRL_prediction(
    model=trained_model, 
    environment = e_trade_gym)
# Out:
# hit end!

# %%
trained_model = trained_ddpg
df_account_value_ddpg, df_actions_ddpg = DRLAgent.DRL_prediction(
    model=trained_model, 
    environment = e_trade_gym)
# Out:
# hit end!

# %%
trained_model = trained_ppo
df_account_value_ppo, df_actions_ppo = DRLAgent.DRL_prediction(
    model=trained_model, 
    environment = e_trade_gym)
# Out:
# hit end!

# %%
trained_model = trained_td3
df_account_value_td3, df_actions_td3 = DRLAgent.DRL_prediction(
    model=trained_model, 
    environment = e_trade_gym)
# Out:
# hit end!

# %%
trained_model = trained_sac
df_account_value_sac, df_actions_sac = DRLAgent.DRL_prediction(
    model=trained_model, 
    environment = e_trade_gym)
# Out:
# hit end!

# %% [markdown]
# ## Part 7: Backtesting Results
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
# df_result_a2c = df_account_value_a2c.set_index(df_account_value_a2c.columns[0])
# df_result_a2c.rename(columns = {'account_value':'a2c'}, inplace = True)
# df_result_ddpg = df_account_value_ddpg.set_index(df_account_value_ddpg.columns[0])
# df_result_ddpg.rename(columns = {'account_value':'ddpg'}, inplace = True)
# df_result_td3 = df_account_value_td3.set_index(df_account_value_td3.columns[0])
# df_result_td3.rename(columns = {'account_value':'td3'}, inplace = True)
df_result_ppo = df_account_value_ppo.set_index(df_account_value_ppo.columns[0])
df_result_ppo.rename(columns = {'account_value':'ppo'}, inplace = True)
# df_result_sac = df_account_value_sac.set_index(df_account_value_sac.columns[0])
# df_result_sac.rename(columns = {'account_value':'sac'}, inplace = True)

result = pd.DataFrame()
# result = pd.merge(result, df_result_a2c, how='outer', left_index=True, right_index=True)
# result = pd.merge(result, df_result_ddpg, how='outer', left_index=True, right_index=True)
# result = pd.merge(result, df_result_td3, how='outer', left_index=True, right_index=True)
result = pd.merge(result, df_result_ppo, how='outer', left_index=True, right_index=True)
# result = pd.merge(result, df_result_sac, how='outer', left_index=True, right_index=True)
print(result.head())
# result.columns = ['a2c', 'ddpg', 'td3', 'ppo', 'sac', 'mean var', 'dji']

# print("result: ", result)
result.to_csv(RESULTS_DIR + "/result.csv")
# Out:
#                  ppo
# date
# 2023-01-03  100000.0
# 2023-01-04  100000.0
# 2023-01-05  100000.0
# 2023-01-06  100000.0
# 2023-01-09  100000.0

# %%
# %matplotlib inline
plt.rcParams["figure.figsize"] = (15,5)
plt.figure();
result.plot();

# %%
trade[['date', 'close']].plot()
# Out:
# <Axes: >

# %%
result.plot()
# Out:
# <Axes: xlabel='date'>
