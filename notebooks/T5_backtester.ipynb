# %%
import os, zipfile, math, logging, datetime
import pandas as pd
import backtrader as bt
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pyfolio as pf
from collections import OrderedDict

matplotlib.use('Qt5Agg')
plt.switch_backend('Qt5Agg')
# Out:
# /Users/HSY/miniconda3/envs/uoa-mdt/lib/python3.10/site-packages/pyfolio/pos.py:26: UserWarning: Module "zipline.assets" not found; mutltipliers will not be applied to position notionals.
#   warnings.warn(

# %% [markdown]
# # Read Data

# %%
# List of symbols to merge
symbols = ['BTCUSDT', 'ETHUSDT']

# List to store individual DataFrames
rawdfs = []

# Loop through each symbol
for symbol in symbols:
    directory = f'../mdt_utils/binance-public-data/python/data/spot/monthly/klines/{symbol}/1h/'
    
    # Loop through each zip file in the directory
    for file_name in os.listdir(directory):
        if file_name.endswith('.zip'):
            with zipfile.ZipFile(os.path.join(directory, file_name), 'r') as zip_ref:
                # only one CSV file in each zip archive
                csv_file = zip_ref.namelist()[0]
                with zip_ref.open(csv_file) as csv_fp:
                    # Read the CSV data into a DataFrame
                    temp_df = pd.read_csv(csv_fp, header=None)
                    temp_df.columns = ['open_time', 'open', 'high', 'low', 'close', 'volume', 'close_time', 'quote_asset_volume', 'number_of_trades', 'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume', 'ignore']
                    # temp_df['date'] = pd.to_datetime(temp_df['close_time'], unit='ms').dt.strftime('%Y-%m-%d')
                    temp_df = temp_df.rename(columns={"close_time": "time"})
                    temp_df['tic'] = symbol
                    rawdfs.append(temp_df[['time', 'open', 'high', 'low', 'close', 'volume', 'tic']])

# Concatenate all DataFrames into a single DataFrame
rawdf = pd.concat(rawdfs, ignore_index=True)

# Count the number of unique 'tic' values per date
tic_counts = rawdf.groupby('time')['tic'].nunique()

# Filter the DataFrame to keep only rows where all 'tic' values participate
df = rawdf[rawdf['time'].isin(tic_counts[tic_counts == len(rawdf['tic'].unique())].index)]
# Only wanted columns
df = df[['time', 'open', 'high', 'low', 'close', 'volume', 'tic']]
df['datetime'] = pd.to_datetime(df['time'], unit='ms')

df = df.sort_values(['time', 'tic'],ignore_index=True)

# df = df.head(100000)
df
# Out:
#                  time      open      high       low     close       volume  \
# 0       1502945999999   4261.48   4313.62   4261.32   4308.83    47.181009
# 1       1502945999999    301.13    302.57    298.00    301.61   125.668770
# 2       1502949599999   4308.83   4328.69   4291.37   4315.32    23.234916
# 3       1502949599999    301.61    303.28    300.00    303.10   377.672460
# 4       1502953199999   4330.29   4345.45   4309.37   4324.35     7.229691
# ...               ...       ...       ...       ...       ...          ...
# 104025  1690840799999   1853.51   1858.77   1851.02   1856.87  5720.590800
# 104026  1690844399999  29243.32  29243.32  29201.00  29209.99   441.450670
# 104027  1690844399999   1856.86   1857.58   1855.01   1856.40  2950.512300
# 104028  1690847999999  29210.00  29240.50  29190.00  29232.25   437.205740
# 104029  1690847999999   1856.41   1857.97   1855.08   1856.14  2825.808500
#
#             tic                datetime
# 0       BTCUSDT 2017-08-17 04:59:59.999
# 1       ETHUSDT 2017-08-17 04:59:59.999
# 2       BTCUSDT 2017-08-17 05:59:59.999
# 3       ETHUSDT 2017-08-17 05:59:59.999
# 4       BTCUSDT 2017-08-17 06:59:59.999
# ...         ...                     ...
# 104025  ETHUSDT 2023-07-31 21:59:59.999
# 104026  BTCUSDT 2023-07-31 22:59:59.999
# 104027  ETHUSDT 2023-07-31 22:59:59.999
# 104028  BTCUSDT 2023-07-31 23:59:59.999
# 104029  ETHUSDT 2023-07-31 23:59:59.999
#
# [104030 rows x 8 columns]

# %%
class PairTrading(bt.Strategy):
    params = dict(
        OPEN_THRE=5,
        CLOS_THRE=0.1,
        period=60
    )

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            return  # Do nothing for submitted or accepted orders

        if order.status == order.Completed:
            if order.isbuy():
                print(f"Buy {order.data._name} @ price: {order.executed.price} for Qty: {order.executed.size}")
            else:
                print(f"Sell {order.data._name} @ price: {order.executed.price} for Qty: {order.executed.size}")

        elif order.status in [order.Expired, order.Canceled, order.Margin]:
            print('%s ,' % order.Status[order.status])
            pass  # Simply log

        # executed_price = order.executed.price
        # action = 'BUY' if order.isbuy() else 'SELL'
        # data_name = order.data._name
        # quantity = order.size

        # if order.status == order.Completed:
        #     if not self.position:
        #         action = 'SELL'

        #     print(f'{action} {data_name} @ price: {executed_price:.2f} for (Qty: {quantity})')
        # else:
        #     print(f'{order.Status[order.status]} for {data_name}')

    
    def __init__(self):
        self.data0 = self.datas[0]
        self.data1 = self.datas[1]

        # self.qty0 = self.qty1 = 0

        self.transform = bt.indicators.OLS_TransformationN(self.data1, self.data0, period=self.p.period)
        # self.ols = bt.indicators.OLS_Slope_InterceptN(self.data1, self.data0, period=self.p.period)

        # self.slope = self.ols.slope
        # self.intercept = self.ols.intercept

        # self.spread = self.transform.spread
        # self.spread_std = self.transform.spread_std
        # self.spread_mean = self.transform.spread_mean
        self.zscore = self.transform.zscore

        # -1 for short data1/data0, 1 for long data1/data0, 0 for no position
        self.position_status = 0

    def next(self):
        # print(f'Right now the zscore is {self.transform.zscore[0]}, and the position is {self.position_status}')

        ratio = self.data1.close[0] / self.data0.close[0]

        if self.zscore[0] > self.params.OPEN_THRE and self.position_status == 0:
            print("------")
            print("long data1 and short data0")
            self.position_status = -1

            self.sell(data=self.data0, size=ratio)
            self.buy(data=self.data1, size=1)
            
            # self.qty0 = -ratio
            # self.qty1 = 1

        elif self.zscore[0] < -self.params.OPEN_THRE and self.position_status == 0:
            print("------")
            print("long data0 and short data1")
            self.position_status = 1
            self.sell(data=self.data0, size=ratio)
            self.buy(data=self.data1, size=1)

            # self.qty0 = -ratio
            # self.qty1 = 1

        elif abs(self.zscore[0]) < self.params.CLOS_THRE and self.position_status != 0:
            print("------")
            print("close position")
            self.position_status = 0
            self.close(data=self.data0)
            self.close(data=self.data1)

            # self.qty0 = self.qty1 = 0

    def stop(self):
        print('==================================================')
        print('Starting Value - %.2f' % self.broker.startingcash)
        print('Ending   Value - %.2f' % self.broker.getvalue())
        print('==================================================')

# %%
datafeed_eth = bt.feeds.PandasData(
    dataname=df[df['tic']=='ETHUSDT'],
    datetime='datetime',
    open='open',
    high='high',
    low='low',
    close='close',
    volume='volume',
    openinterest=None  # You can specify open interest if your data includes it, otherwise set it to None
)

datafeed_btc = bt.feeds.PandasData(
    dataname=df[df['tic']=='BTCUSDT'],
    datetime='datetime',
    open='open',
    high='high',
    low='low',
    close='close',
    volume='volume',
    openinterest=None  # You can specify open interest if your data includes it, otherwise set it to None
)

# %%
# Create a Cerebro instance and add the data feed
cerebro = bt.Cerebro()
cerebro.adddata(datafeed_eth, name='eth')
cerebro.adddata(datafeed_btc, name='btc')

# Set up other parameters for your backtest
cerebro.broker.set_cash(100000)  # Set your initial capital
cerebro.broker.setcommission(commission=0.001)  # Set commission rate

# Add your trading strategy to Cerebro and run the backtest
cerebro.addstrategy(PairTrading)
cerebro.addanalyzer(bt.analyzers.TimeReturn, _name='timereturns')

strats = cerebro.run()
# Out:
# ------
# long data1 and short data0
# Sell eth @ price: 730.96 for Qty: -20.09595613433859
# Buy btc @ price: 14686.98 for Qty: 1
# ------
# close position
# Buy eth @ price: 744.45 for Qty: 20.09595613433859
# Sell btc @ price: 15787.95 for Qty: -1
# ------
# long data1 and short data0
# Sell eth @ price: 854.71 for Qty: -17.05402781514276
# Buy btc @ price: 14576.87 for Qty: 1
# ------
# close position
# Buy eth @ price: 868.77 for Qty: 17.05402781514276
# Sell btc @ price: 15002.59 for Qty: -1
# ------
# long data0 and short data1
# Sell eth @ price: 402.7 for Qty: -16.84132108269183
# Buy btc @ price: 6782.99 for Qty: 1
# ------
# close position
# Buy eth @ price: 400.85 for Qty: 16.84132108269183
# Sell btc @ price: 6778.0 for Qty: -1
# ------
# long data1 and short data0
# Sell eth @ price: 460.31 for Qty: -16.705769899200558
# Buy btc @ price: 7685.55 for Qty: 1
# ------
# close position
# Buy eth @ price: 492.63 for Qty: 16.705769899200558
# Sell btc @ price: 7890.0 for Qty: -1
# ------
# long data0 and short data1
# Sell eth @ price: 684.97 for Qty: -13.423764197494817
# Buy btc @ price: 9195.01 for Qty: 1
# ------
# close position
# Buy eth @ price: 633.3999999999999 for Qty: 13.423764197494817
# Sell btc @ price: 8955.13 for Qty: -1
# ------
# long data1 and short data0
# Sell eth @ price: 513.7 for Qty: -13.098016313340729
# Buy btc @ price: 6725.03 for Qty: 1
# ------
# close position
# Buy eth @ price: 524.64 for Qty: 13.098016313340729
# Sell btc @ price: 6765.0 for Qty: -1
# ------
# long data0 and short data1
# Sell eth @ price: 225.46 for Qty: -28.64121088555979
# Buy btc @ price: 6462.03 for Qty: 1
# ------
# close position
# Buy eth @ price: 227.13 for Qty: 28.64121088555979
# Sell btc @ price: 6464.64 for Qty: -1
# ------
# long data1 and short data0
# Sell eth @ price: 235.09 for Qty: -31.532042553191488
# Buy btc @ price: 7410.09 for Qty: 1
# ------
# close position
# Buy eth @ price: 215.77 for Qty: 31.532042553191488
# Sell btc @ price: 6878.0 for Qty: -1
# ------
# long data0 and short data1
# Sell eth @ price: 189.63 for Qty: -31.45657332700522
# Buy btc @ price: 5965.57 for Qty: 1
# ------
# close position
# Buy eth @ price: 181.88 for Qty: 31.45657332700522
# Sell btc @ price: 5745.39 for Qty: -1
# ------
# long data1 and short data0
# Sell eth @ price: 103.43 for Qty: -37.40208776338682
# Buy btc @ price: 3870.0 for Qty: 1
# ------
# close position
# Buy eth @ price: 84.56 for Qty: 37.40208776338682
# Sell btc @ price: 3376.57 for Qty: -1
# ------
# long data0 and short data1
# Sell eth @ price: 133.0 for Qty: -27.80735947023855
# Buy btc @ price: 3696.71 for Qty: 1
# ------
# close position
# Buy eth @ price: 135.73 for Qty: 27.80735947023855
# Sell btc @ price: 3768.0 for Qty: -1
# ------
# long data1 and short data0
# Sell eth @ price: 153.01 for Qty: -25.992810927390366
# Buy btc @ price: 3980.57 for Qty: 1
# ------
# close position
# Buy eth @ price: 152.92 for Qty: 25.992810927390366
# Sell btc @ price: 3987.89 for Qty: -1
# ------
# long data0 and short data1
# Sell eth @ price: 124.34 for Qty: -28.813203602444517
# Buy btc @ price: 3583.21 for Qty: 1
# ------
# close position
# Buy eth @ price: 125.87 for Qty: 28.813203602444517
# Sell btc @ price: 3591.17 for Qty: -1
# ------
# long data1 and short data0
# Sell eth @ price: 156.07 for Qty: -26.229823212913143
# Buy btc @ price: 4095.0 for Qty: 1
# ------
# close position
# Buy eth @ price: 163.89000000000001 for Qty: 26.229823212913143
# Sell btc @ price: 4170.63 for Qty: -1
# ------
# long data1 and short data0
# Sell eth @ price: 141.23 for Qty: -29.192424778761065
# Buy btc @ price: 4120.18 for Qty: 1
# ------
# close position
# Buy eth @ price: 143.12 for Qty: 29.192424778761065
# Sell btc @ price: 4103.58 for Qty: -1
# ------
# long data0 and short data1
# Sell eth @ price: 149.38 for Qty: -31.28072522914297
# Buy btc @ price: 4677.1 for Qty: 1
# ------
# close position
# Buy eth @ price: 155.2 for Qty: 31.28072522914297
# Sell btc @ price: 4733.85 for Qty: -1
# ------
# long data1 and short data0
# Sell eth @ price: 163.19 for Qty: -35.30805048400931
# Buy btc @ price: 5762.97 for Qty: 1
# ------
# close position
# Buy eth @ price: 170.49 for Qty: 35.30805048400931
# Sell btc @ price: 5883.94 for Qty: -1
# ------
# long data1 and short data0
# Sell eth @ price: 187.61 for Qty: -51.373806348359565
# Buy btc @ price: 9630.43 for Qty: 1
# ------
# close position
# Buy eth @ price: 179.52 for Qty: 51.373806348359565
# Sell btc @ price: 9217.6 for Qty: -1
# ------
# long data1 and short data0
# Sell eth @ price: 186.71 for Qty: -50.59855382967328
# Buy btc @ price: 9448.07 for Qty: 1
# ------
# close position
# Buy eth @ price: 185.14 for Qty: 50.59855382967328
# Sell btc @ price: 9370.9 for Qty: -1
# ------
# long data0 and short data1
# Sell eth @ price: 132.2 for Qty: -54.94211123723042
# Buy btc @ price: 7260.64 for Qty: 1
# ------
# close position
# Buy eth @ price: 133.76 for Qty: 54.94211123723042
# Sell btc @ price: 7336.75 for Qty: -1
# ------
# long data1 and short data0
# Sell eth @ price: 143.76 for Qty: -54.868331362593025
# Buy btc @ price: 7889.64 for Qty: 1
# ------
# close position
# Buy eth @ price: 143.17 for Qty: 54.868331362593025
# Sell btc @ price: 7884.32 for Qty: -1
# ------
# long data1 and short data0
# Sell eth @ price: 175.3 for Qty: -52.16460388980779
# Buy btc @ price: 9146.91 for Qty: 1
# ------
# close position
# Buy eth @ price: 164.43 for Qty: 52.16460388980779
# Sell btc @ price: 8617.1 for Qty: -1
# ------
# long data0 and short data1
# Sell eth @ price: 232.04999999999998 for Qty: -38.11253825266152
# Buy btc @ price: 8842.27 for Qty: 1
# ------
# close position
# Buy eth @ price: 235.79 for Qty: 38.11253825266152
# Sell btc @ price: 8912.22 for Qty: -1
# ------
# long data1 and short data0
# Sell eth @ price: 189.26 for Qty: -39.82224570673712
# Buy btc @ price: 7537.27 for Qty: 1
# ------
# close position
# Buy eth @ price: 189.28 for Qty: 39.82224570673712
# Sell btc @ price: 7539.0 for Qty: -1
# ------
# long data1 and short data0
# Sell eth @ price: 208.4 for Qty: -39.806525911708256
# Buy btc @ price: 8296.43 for Qty: 1
# ------
# close position
# Buy eth @ price: 209.05000000000004 for Qty: 39.806525911708256
# Sell btc @ price: 8761.91 for Qty: -1
# ------
# long data1 and short data0
# Sell eth @ price: 248.23000000000002 for Qty: -41.09402570196995
# Buy btc @ price: 10202.71 for Qty: 1
# ------
# close position
# Buy eth @ price: 236.23 for Qty: 41.09402570196995
# Sell btc @ price: 9497.63 for Qty: -1
# ------
# long data1 and short data0
# Sell eth @ price: 243.01 for Qty: -39.87001069870792
# Buy btc @ price: 9688.58 for Qty: 1
# ------
# close position
# Buy eth @ price: 242.74000000000004 for Qty: 39.87001069870792
# Sell btc @ price: 9631.69 for Qty: -1
# ------
# long data1 and short data0
# Sell eth @ price: 313.8 for Qty: -31.35427023581899
# Buy btc @ price: 9837.58 for Qty: 1
# ------
# close position
# Buy eth @ price: 311.02 for Qty: 31.35427023581899
# Sell btc @ price: 9931.54 for Qty: -1
# ------
# long data1 and short data0
# Sell eth @ price: 323.72 for Qty: -33.58737759105372
# Buy btc @ price: 10872.56 for Qty: 1
# ------
# close position
# Buy eth @ price: 310.22 for Qty: 33.58737759105372
# Sell btc @ price: 10770.17 for Qty: -1
# ------
# long data1 and short data0
# Sell eth @ price: 438.57 for Qty: -27.1729295877417
# Buy btc @ price: 11917.25 for Qty: 1
# ------
# close position
# Buy eth @ price: 435.75 for Qty: 27.1729295877417
# Sell btc @ price: 11879.27 for Qty: -1
# ------
# long data1 and short data0
# Sell eth @ price: 608.61 for Qty: -31.19253015215748
# Buy btc @ price: 18983.16 for Qty: 1
# ------
# close position
# Buy eth @ price: 584.61 for Qty: 31.19253015215748
# Sell btc @ price: 18808.04 for Qty: -1
# ------
# long data0 and short data1
# Sell eth @ price: 3260.74 for Qty: -16.960335085857317
# Buy btc @ price: 55294.47 for Qty: 1
# ------
# close position
# Buy eth @ price: 3480.01 for Qty: 16.960335085857317
# Sell btc @ price: 56143.43 for Qty: -1
# ------
# long data0 and short data1
# Sell eth @ price: 4233.85 for Qty: -12.505767136651494
# Buy btc @ price: 52938.97 for Qty: 1
# ------
# close position
# Buy eth @ price: 3822.54 for Qty: 12.505767136651494
# Sell btc @ price: 50029.77 for Qty: -1
# ------
# long data0 and short data1
# Sell eth @ price: 2686.5 for Qty: -14.159453413189704
# Buy btc @ price: 38038.67 for Qty: 1
# ------
# close position
# Buy eth @ price: 2876.99 for Qty: 14.159453413189704
# Sell btc @ price: 42423.87 for Qty: -1
# ------
# long data1 and short data0
# Sell eth @ price: 3312.9599999999996 for Qty: -13.926747257059205
# Buy btc @ price: 46140.01 for Qty: 1
# ------
# close position
# Buy eth @ price: 3202.63 for Qty: 13.926747257059205
# Sell btc @ price: 44361.97 for Qty: -1
# ------
# long data1 and short data0
# Sell eth @ price: 3456.25 for Qty: -15.259975522320692
# Buy btc @ price: 52741.68 for Qty: 1
# ------
# close position
# Buy eth @ price: 3532.33 for Qty: 15.259975522320692
# Sell btc @ price: 55075.57 for Qty: -1
# ------
# long data1 and short data0
# Sell eth @ price: 1808.16 for Qty: -17.282440553525323
# Buy btc @ price: 31259.96 for Qty: 1
# ------
# close position
# Buy eth @ price: 1790.63 for Qty: 17.282440553525323
# Sell btc @ price: 30140.14 for Qty: -1
# ------
# long data1 and short data0
# Sell eth @ price: 1540.52 for Qty: -15.019137389317338
# Buy btc @ price: 23128.31 for Qty: 1
# ------
# close position
# Buy eth @ price: 1539.69 for Qty: 15.019137389317338
# Sell btc @ price: 23256.89 for Qty: -1
# ------
# long data1 and short data0
# Sell eth @ price: 1317.59 for Qty: -14.884373102610809
# Buy btc @ price: 19613.0 for Qty: 1
# ------
# close position
# Buy eth @ price: 1347.77 for Qty: 14.884373102610809
# Sell btc @ price: 19938.29 for Qty: -1
# ------
# long data0 and short data1
# Sell eth @ price: 1365.5 for Qty: -14.348455888276174
# Buy btc @ price: 19592.96 for Qty: 1
# ------
# close position
# Buy eth @ price: 1349.32 for Qty: 14.348455888276174
# Sell btc @ price: 19373.62 for Qty: -1
# ------
# long data1 and short data0
# Sell eth @ price: 1333.16 for Qty: -13.666286494638825
# Buy btc @ price: 18222.21 for Qty: 1
# ------
# close position
# Buy eth @ price: 1310.94 for Qty: 13.666286494638825
# Sell btc @ price: 17831.61 for Qty: -1
# ------
# long data0 and short data1
# Sell eth @ price: 1898.5 for Qty: -16.013005072452316
# Buy btc @ price: 30400.54 for Qty: 1
# ------
# close position
# Buy eth @ price: 1922.74 for Qty: 16.013005072452316
# Sell btc @ price: 30577.65 for Qty: -1
# ------
# long data1 and short data0
# Sell eth @ price: 1968.17 for Qty: -15.785546980189718
# Buy btc @ price: 31068.64 for Qty: 1
# ------
# close position
# Buy eth @ price: 1941.57 for Qty: 15.785546980189718
# Sell btc @ price: 30820.01 for Qty: -1
# ==================================================
# Starting Value - 100000.00
# Ending   Value - 100529.86
# ==================================================

# %%
# The error message is an open issue on Github:
# https://github.com/quantopian/pyfolio/issues/652

strat = strats[0]
timereturns_analyzer = strat.analyzers.getbyname('timereturns')
timereturns = timereturns_analyzer.get_analysis()
series_timereturns = pd.Series(timereturns)
pf.create_full_tear_sheet(series_timereturns)
# Out:
# /Users/HSY/miniconda3/envs/uoa-mdt/lib/python3.10/site-packages/pyfolio/timeseries.py:724: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   stats = pd.Series()
# /Users/HSY/miniconda3/envs/uoa-mdt/lib/python3.10/site-packages/empyrical/stats.py:1527: RuntimeWarning: invalid value encountered in double_scalars
#   return np.abs(np.percentile(returns, 95)) / \
# /Users/HSY/miniconda3/envs/uoa-mdt/lib/python3.10/site-packages/pyfolio/plotting.py:648: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for stat, value in perf_stats[column].iteritems():
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2017-08-17</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2023-07-31</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>103</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>0.1%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>0.5%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>1.5%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.05</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.02</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.19</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-3.1%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.07</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>0.06</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-11.07</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>575.44</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-0.2%</td>
#     </tr>
#   </tbody>
# </table>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/HSY/PhD/MDT/notebooks/T5_backtester.ipynb Cell 7 line 8
#       <a href='vscode-notebook-cell:/Users/HSY/PhD/MDT/notebooks/T5_backtester.ipynb#X11sZmlsZQ%3D%3D?line=5'>6</a> timereturns = timereturns_analyzer.get_analysis()
#       <a href='vscode-notebook-cell:/Users/HSY/PhD/MDT/notebooks/T5_backtester.ipynb#X11sZmlsZQ%3D%3D?line=6'>7</a> series_timereturns = pd.Series(timereturns)
# ----> <a href='vscode-notebook-cell:/Users/HSY/PhD/MDT/notebooks/T5_backtester.ipynb#X11sZmlsZQ%3D%3D?line=7'>8</a> pf.create_full_tear_sheet(series_timereturns)
#
# File ~/miniconda3/envs/uoa-mdt/lib/python3.10/site-packages/pyfolio/tears.py:201, in create_full_tear_sheet(returns, positions, transactions, market_data, benchmark_rets, slippage, live_start_date, sector_mappings, bayesian, round_trips, estimate_intraday, hide_positions, cone_std, bootstrap, unadjusted_returns, style_factor_panel, sectors, caps, shares_held, volumes, percentile, turnover_denom, set_context, factor_returns, factor_loadings, pos_in_dollars, header_rows, factor_partitions)
#     195     returns = txn.adjust_returns_for_slippage(returns, positions,
#     196                                               transactions, slippage)
#     198 positions = utils.check_intraday(estimate_intraday, returns,
#     199                                  positions, transactions)
# --> 201 create_returns_tear_sheet(
#     202     returns,
#     203     positions=positions,
#     204     transactions=transactions,
#     205     live_start_date=live_start_date,
#     206     cone_std=cone_std,
#     207     benchmark_rets=benchmark_rets,
#     208     bootstrap=bootstrap,
#     209     turnover_denom=turnover_denom,
#     210     header_rows=header_rows,
#     211     set_context=set_context)
#     213 create_interesting_times_tear_sheet(returns,
#     214                                     benchmark_rets=benchmark_rets,
#     215                                     set_context=set_context)
#     217 if positions is not None:
#
# File ~/miniconda3/envs/uoa-mdt/lib/python3.10/site-packages/pyfolio/plotting.py:52, in customize.<locals>.call_w_context(*args, **kwargs)
#      50 if set_context:
#      51     with plotting_context(), axes_style():
# ---> 52         return func(*args, **kwargs)
#      53 else:
#      54     return func(*args, **kwargs)
#
# File ~/miniconda3/envs/uoa-mdt/lib/python3.10/site-packages/pyfolio/tears.py:504, in create_returns_tear_sheet(returns, positions, transactions, live_start_date, cone_std, benchmark_rets, bootstrap, turnover_denom, header_rows, return_fig)
#     494     returns = utils.clip_returns_to_benchmark(returns, benchmark_rets)
#     496 plotting.show_perf_stats(returns, benchmark_rets,
#     497                          positions=positions,
#     498                          transactions=transactions,
#    (...)
#     501                          live_start_date=live_start_date,
#     502                          header_rows=header_rows)
# --> 504 plotting.show_worst_drawdown_periods(returns)
#     506 vertical_sections = 11
#     508 if live_start_date is not None:
#
# File ~/miniconda3/envs/uoa-mdt/lib/python3.10/site-packages/pyfolio/plotting.py:1664, in show_worst_drawdown_periods(returns, top)
#    1648 def show_worst_drawdown_periods(returns, top=5):
#    1649     """
#    1650     Prints information about the worst drawdown periods.
#    1651
#    (...)
#    1661         Amount of top drawdowns periods to plot (default 5).
#    1662     """
# -> 1664     drawdown_df = timeseries.gen_drawdown_table(returns, top=top)
#    1665     utils.print_table(
#    1666         drawdown_df.sort_values('Net drawdown in %', ascending=False),
#    1667         name='Worst drawdown periods',
#    1668         float_format='{0:.2f}'.format,
#    1669     )
#
# File ~/miniconda3/envs/uoa-mdt/lib/python3.10/site-packages/pyfolio/timeseries.py:1008, in gen_drawdown_table(returns, top)
#    1003     df_drawdowns.loc[i, 'Duration'] = len(pd.date_range(peak,
#    1004                                                         recovery,
#    1005                                                         freq='B'))
#    1006 df_drawdowns.loc[i, 'Peak date'] = (peak.to_pydatetime()
#    1007                                     .strftime('%Y-%m-%d'))
# -> 1008 df_drawdowns.loc[i, 'Valley date'] = (valley.to_pydatetime()
#    1009                                       .strftime('%Y-%m-%d'))
#    1010 if isinstance(recovery, float):
#    1011     df_drawdowns.loc[i, 'Recovery date'] = recovery
#
# AttributeError: 'numpy.int64' object has no attribute 'to_pydatetime'

# %%
cerebro.plot(stdstats=False, iplot=False)
